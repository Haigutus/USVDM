# %%
# notebook specific things
from IPython.display import HTML, Markdown, display

display(HTML("<style>.container { width:90% !important; }</style>")) # Change report layout width

def markdown_print(string):
    display(Markdown(string))

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <style>.container { width:90% !important; }</style>
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
#-------------------------------------------------------------------------------
# Name:        RDFS Comparison
# Purpose:     Compare different versions of RDFS
#
# Author:      kristjan.vilgo
#
# Created:     01.02.2020
# Copyright:   (c) kristjan.vilgo 2020
# Licence:     GPL V2
#-------------------------------------------------------------------------------
import sys
sys.path.append("..")

import pandas

from RDF_parser import *
from RDFS_tools import *

# Set pandas display options
pandas.set_option('display.max_columns', 200)
pandas.set_option('display.max_rows', 350)
pandas.set_option('display.min_rows', 350)
pandas.set_option('display.expand_frame_repr', True)

# %%
# Load RDFS

path_old = r"..\rdfs\ENTSOE_CGMES_v2.4.15_04Jul2016_RDFS.zip"
path_new = r"..\rdfs\RDFS_UML_FDIS06_27Jan2020.zip"

data_new = pandas.read_RDF([path_new])
data_old = pandas.read_RDF([path_old])

data_set = {"new":data_new, "old": data_old}
# Out:
# WARNING 2 - Not supported file: RDFS_UML_FDIS06_27Jan2020/
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_DL.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_DY.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_EQBD.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_EQCO.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_GL.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_OP.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_SC.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_SSH.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_SV.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_TP.rdf
# INFO - Loading RDFS_UML_FDIS06_27Jan2020/IEC61970-600-2_CDV_CGMES_3_0_0_TPBD.rdf
# INFO - Loading EquipmentProfileCoreShortCircuitRDFSAugmented-v2_4_15-4Jul2016.rdf
# INFO - Loading GeographicalLocationProfileRDFSAugmented-v2_4_15-16Feb2016.rdf
# INFO - Loading StateVariablesProfileRDFSAugmented-v2_4_15-16Feb2016.rdf
# INFO - Loading SteadyStateHypothesisProfileRDFSAugmented-v2_4_15-16Feb2016.rdf
# INFO - Loading TopologyBoundaryProfileRDFSAugmented-v2_4_15-16Feb2016.rdf
# INFO - Loading TopologyProfileRDFSAugmented-v2_4_15-16Feb2016.rdf
# INFO - Loading DiagramLayoutProfileRDFSAugmented-v2_4_15-16Feb2016.rdf
# INFO - Loading DynamicsProfileRDFSAugmented_noAbstract-v2_4_15-16Feb2016.rdf
# INFO - Loading DynamicsProfileRDFSAugmented-v2_4_15-16Feb2016.rdf
# INFO - Loading EquipmentBoundaryProfileRDFSAugmented-v2_4_15-16Feb2016.rdf
# INFO - Loading EquipmentProfileCoreOperationRDFSAugmented-v2_4_15-4Jul2016.rdf
# INFO - Loading EquipmentProfileCoreRDFSAugmented-v2_4_15-4Jul2016.rdf
# INFO - Loading EquipmentProfileCoreShortCircuitOperationRDFSAugmented-v2_4_15-4Jul2016.rdf

# %%
markdown_print("# Profiles")

profiles = {}
for data in data_set:
    profiles[data] = pandas.DataFrame(data_set[data]["INSTANCE_ID"].unique())

#for profiles
profiles["new"].merge(profiles["old"], how="outer", indicator="diff").replace({'left_only': r'added', 'right_only': 'removed'}).rename(columns={0:"Profile"})
# Out:
# # Profiles
#                                   Profile     diff
# 0   #Package_DiagramLayoutProfile          both
# 1   #Package_DynamicsProfile               both
# 2   #Package_EquipmentBoundaryProfile      both
# 3   #Package_CoreEquipmentProfile          added
# 4   #Package_GeographicalLocationProfile   both
# 5   #Package_OperationProfile              added
# 6   #Package_ShortCircuitProfile           added
# 7   #Package_SteadyStateHypothesisProfile  both
# 8   #Package_StateVariablesProfile         both
# 9   #Package_TopologyProfile               both
# 10  #Package_TopologyBoundaryProfile       both
# 11  #Package_EquipmentProfile              removed

# %%
report_name = "ConcreteClass"

markdown_print("# {}".format(report_name))

comparison = {}
for data in data_set:
    
    # Here goes query
    comparison[data] = pandas.DataFrame(data_set[data].query("VALUE=='http://iec.ch/TC57/NonStandard/UML#concrete'").ID.unique())

#for profiles
diff = comparison["new"].merge(comparison["old"], how="outer", indicator="diff").replace({'left_only': r'added', 'right_only': 'removed'}).rename(columns={0:report_name})

markdown_print("## Summary")
display(diff["diff"].value_counts())

markdown_print("## Removed")
removed = diff.query("diff=='removed'")
display(removed.merge(data_set["old"], left_on=report_name, right_on="ID")[[report_name, "diff", "INSTANCE_ID"]].drop_duplicates())

markdown_print("## Added")
added = diff.query("diff=='added'")
display(added.merge(data_set["new"], left_on=report_name, right_on="ID")[[report_name, "diff", "INSTANCE_ID"]].drop_duplicates())
# Out:
# # ConcreteClass
# ## Summary
# both       318
# added      44
# removed    9
# Name: diff, dtype: int64
# ## Removed
#                                                      ConcreteClass     diff                        INSTANCE_ID
# 0    #DCEquipmentContainer                                          removed  #Package_EquipmentProfile
# 7    #DCEquipmentContainer                                          removed  #Package_TopologyProfile
# 33   #PerLengthDCLineParameter                                      removed  #Package_EquipmentProfile
# 53   #TapChangerTablePoint                                          removed  #Package_EquipmentProfile
# 73   #WindAeroLinearIEC                                             removed  #Package_DynamicsProfile
# 87   #WindGenTurbineType1IEC                                        removed  #Package_DynamicsProfile
# 101  #WindGenTurbineType3aIEC                                       removed  #Package_DynamicsProfile
# 115  #WindGenTurbineType3bIEC                                       removed  #Package_DynamicsProfile
# 129  #WindPitchContEmulIEC                                          removed  #Package_DynamicsProfile
# 143  http://entsoe.eu/CIM/SchemaExtension/3/1#EnergySchedulingType  removed  #Package_EquipmentBoundaryProfile
# ## Added
#                                                        ConcreteClass   diff                            INSTANCE_ID
# 0    #CSCUserDefined                                                  added  #Package_DynamicsProfile
# 7    #SVCUserDefined                                                  added  #Package_DynamicsProfile
# 14   #VSCUserDefined                                                  added  #Package_DynamicsProfile
# 21   #GovSteamBB                                                      added  #Package_DynamicsProfile
# 28   #ExcNI                                                           added  #Package_DynamicsProfile
# 35   #ExcRQB                                                          added  #Package_DynamicsProfile
# 42   #PssRQB                                                          added  #Package_DynamicsProfile
# 49   #PssSTAB2A                                                       added  #Package_DynamicsProfile
# 56   #WindAeroOneDimIEC                                               added  #Package_DynamicsProfile
# 63   #WindAeroTwoDimIEC                                               added  #Package_DynamicsProfile
# 70   #WindContQLimIEC                                                 added  #Package_DynamicsProfile
# 77   #WindContQPQULimIEC                                              added  #Package_DynamicsProfile
# 84   #WindGenTurbineType1aIEC                                         added  #Package_DynamicsProfile
# 91   #WindGenTurbineType1bIEC                                         added  #Package_DynamicsProfile
# 98   #WindGenType3aIEC                                                added  #Package_DynamicsProfile
# 105  #WindGenType3bIEC                                                added  #Package_DynamicsProfile
# 112  #WindGenType4IEC                                                 added  #Package_DynamicsProfile
# 119  #WindPitchContPowerIEC                                           added  #Package_DynamicsProfile
# 126  #WindRefFrameRotIEC                                              added  #Package_DynamicsProfile
# 133  #WindTurbineType3IEC                                             added  #Package_DynamicsProfile
# 140  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint    added  #Package_EquipmentBoundaryProfile
# 148  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint    added  #Package_CoreEquipmentProfile
# 156  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint    added  #Package_GeographicalLocationProfile
# 165  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint    added  #Package_TopologyProfile
# 174  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint    added  #Package_TopologyBoundaryProfile
# 183  #BatteryUnit                                                     added  #Package_CoreEquipmentProfile
# 190  #BatteryUnit                                                     added  #Package_SteadyStateHypothesisProfile
# 198  #CAESPlant                                                       added  #Package_CoreEquipmentProfile
# 205  #Clamp                                                           added  #Package_CoreEquipmentProfile
# 212  #CogenerationPlant                                               added  #Package_CoreEquipmentProfile
# 219  #CombinedCyclePlant                                              added  #Package_CoreEquipmentProfile
# 226  #CurrentTransformer                                              added  #Package_CoreEquipmentProfile
# 233  #Cut                                                             added  #Package_CoreEquipmentProfile
# 240  #DisconnectingCircuitBreaker                                     added  #Package_CoreEquipmentProfile
# 247  #DisconnectingCircuitBreaker                                     added  #Package_SteadyStateHypothesisProfile
# 255  #FaultIndicator                                                  added  #Package_CoreEquipmentProfile
# 262  #Fuse                                                            added  #Package_CoreEquipmentProfile
# 269  #Fuse                                                            added  #Package_SteadyStateHypothesisProfile
# 277  #Jumper                                                          added  #Package_CoreEquipmentProfile
# 284  #Jumper                                                          added  #Package_SteadyStateHypothesisProfile
# 292  #PhotoVoltaicUnit                                                added  #Package_CoreEquipmentProfile
# 299  #PostLineSensor                                                  added  #Package_CoreEquipmentProfile
# 306  #PotentialTransformer                                            added  #Package_CoreEquipmentProfile
# 313  #PowerElectronicsConnection                                      added  #Package_DynamicsProfile
# 320  #PowerElectronicsConnection                                      added  #Package_CoreEquipmentProfile
# 327  #PowerElectronicsConnection                                      added  #Package_SteadyStateHypothesisProfile
# 335  #PowerElectronicsWindUnit                                        added  #Package_CoreEquipmentProfile
# 342  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#SolarPowerPlant  added  #Package_CoreEquipmentProfile
# 350  #SurgeArrester                                                   added  #Package_CoreEquipmentProfile
# 357  #WaveTrap                                                        added  #Package_CoreEquipmentProfile
# 364  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#WindPowerPlant   added  #Package_CoreEquipmentProfile
# 372  #ServiceLocation                                                 added  #Package_GeographicalLocationProfile
# 379  #Equipment                                                       added  #Package_DynamicsProfile
# 386  #Equipment                                                       added  #Package_EquipmentBoundaryProfile
# 392  #Equipment                                                       added  #Package_CoreEquipmentProfile
# 398  #Equipment                                                       added  #Package_OperationProfile
# 404  #Equipment                                                       added  #Package_ShortCircuitProfile
# 410  #Equipment                                                       added  #Package_SteadyStateHypothesisProfile
# 417  #SvSwitch                                                        added  #Package_StateVariablesProfile

# %%
#data_set["new"].references_to("#ACLineSegment")
# TODO show all new classes

# %%
report_name = "UsedAssociations"

markdown_print("# {}".format(report_name))

properties = {}
for data in data_set:
    
    # Here goes query
    used_properties = data_set[data].query("KEY == 'AssociationUsed' & VALUE == 'Yes'").merge(data_set[data], on="ID", suffixes=("remove",""))[data_set[data].columns]
    properties[data] = pandas.DataFrame(used_properties.query("VALUE == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property'").ID.unique())

#for profiles
diff = properties["new"].merge(properties["old"], how="outer", indicator="diff").replace({'left_only': r'added', 'right_only': 'removed'}).rename(columns={0:report_name})

markdown_print("## Summary")
display(diff["diff"].value_counts())

markdown_print("## Removed")
removed = diff.query("diff=='removed'")
display(removed.merge(data_set["old"], left_on=report_name, right_on="ID")[[report_name, "diff", "INSTANCE_ID"]].drop_duplicates())

markdown_print("## Added")
added = diff.query("diff=='added'")
display(added.merge(data_set["new"], left_on=report_name, right_on="ID")[[report_name, "diff", "INSTANCE_ID"]].drop_duplicates())
# Out:
# # UsedAssociations
# ## Summary
# both       181
# added      42
# removed    9
# Name: diff, dtype: int64
# ## Removed
#                                                                UsedAssociations     diff                        INSTANCE_ID
# 0    #WindTurbineType3or4Dynamics.EnergySource                                   removed  #Package_DynamicsProfile
# 18   #WindGenTurbineType1IEC.WindAeroConstIEC                                    removed  #Package_DynamicsProfile
# 38   #WindGenTurbineType3IEC.WindAeroLinearIEC                                   removed  #Package_DynamicsProfile
# 58   #WindGenTurbineType3IEC.WindContPitchAngleIEC                               removed  #Package_DynamicsProfile
# 78   #WindGenTurbineType3IEC.WindContPType3IEC                                   removed  #Package_DynamicsProfile
# 98   #WindGenTurbineType2IEC.WindPitchContEmulIEC                                removed  #Package_DynamicsProfile
# 118  #WindGenTurbineType3IEC.WindMechIEC                                         removed  #Package_DynamicsProfile
# 138  http://entsoe.eu/CIM/SchemaExtension/3/1#EnergySource.EnergySchedulingType  removed  #Package_EquipmentBoundaryProfile
# 148  #DCLineSegment.PerLengthParameter                                           removed  #Package_EquipmentProfile
# ## Added
#                                                                         UsedAssociations   diff                           INSTANCE_ID
# 0    #WindTurbineType3or4Dynamics.PowerElectronicsConnection                              added  #Package_DynamicsProfile
# 9    #StaticVarCompensatorDynamics.StaticVarCompensator                                   added  #Package_DynamicsProfile
# 18   #CSCDynamics.CSConverter                                                             added  #Package_DynamicsProfile
# 27   #VSCDynamics.VsConverter                                                             added  #Package_DynamicsProfile
# 36   #ProprietaryParameterDynamics.CSCUserDefined                                         added  #Package_DynamicsProfile
# 45   #ProprietaryParameterDynamics.SVCUserDefined                                         added  #Package_DynamicsProfile
# 54   #ProprietaryParameterDynamics.VSCUserDefined                                         added  #Package_DynamicsProfile
# 63   #CrossCompoundTurbineGovernorDynamics.HighPressureSynchronousMachineDynamics         added  #Package_DynamicsProfile
# 72   #CrossCompoundTurbineGovernorDynamics.LowPressureSynchronousMachineDynamics          added  #Package_DynamicsProfile
# 81   #WindGenTurbineType1aIEC.WindAeroConstIEC                                            added  #Package_DynamicsProfile
# 90   #WindTurbineType3IEC.WindAeroOneDimIEC                                               added  #Package_DynamicsProfile
# 99   #WindTurbineType3IEC.WindAeroTwoDimIEC                                               added  #Package_DynamicsProfile
# 108  #WindTurbineType3IEC.WindContPitchAngleIEC                                           added  #Package_DynamicsProfile
# 117  #WindTurbineType3IEC.WindContPType3IEC                                               added  #Package_DynamicsProfile
# 126  #WindTurbineType3or4IEC.WindContQLimIEC                                              added  #Package_DynamicsProfile
# 135  #WindTurbineType3or4IEC.WindContQPQULimIEC                                           added  #Package_DynamicsProfile
# 144  #WindDynamicsLookupTable.WindContQPQULimIEC                                          added  #Package_DynamicsProfile
# 153  #WindDynamicsLookupTable.WindProtectionIEC                                           added  #Package_DynamicsProfile
# 162  #WindDynamicsLookupTable.WindPlantReactiveControlIEC                                 added  #Package_DynamicsProfile
# 171  #WindDynamicsLookupTable.WindGenType3bIEC                                            added  #Package_DynamicsProfile
# 180  #WindDynamicsLookupTable.WindPitchContPowerIEC                                       added  #Package_DynamicsProfile
# 189  #WindGenTurbineType1bIEC.WindPitchContPowerIEC                                       added  #Package_DynamicsProfile
# 198  #WindGenTurbineType2IEC.WindPitchContPowerIEC                                        added  #Package_DynamicsProfile
# 207  #WindTurbineType4IEC.WindGenType3aIEC                                                added  #Package_DynamicsProfile
# 216  #WindTurbineType3IEC.WindGenType3IEC                                                 added  #Package_DynamicsProfile
# 225  #WindTurbineType4aIEC.WindGenType4IEC                                                added  #Package_DynamicsProfile
# 234  #WindTurbineType4bIEC.WindGenType4IEC                                                added  #Package_DynamicsProfile
# 243  #WindTurbineType3IEC.WindMechIEC                                                     added  #Package_DynamicsProfile
# 252  #WindTurbineType3or4IEC.WindRefFrameRotIEC                                           added  #Package_DynamicsProfile
# 261  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint.ConnectivityNode       added  #Package_EquipmentBoundaryProfile
# 271  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint.ConnectivityNode       added  #Package_CoreEquipmentProfile
# 281  #Clamp.ACLineSegment                                                                 added  #Package_CoreEquipmentProfile
# 290  #Cut.ACLineSegment                                                                   added  #Package_CoreEquipmentProfile
# 299  #AuxiliaryEquipment.Terminal                                                         added  #Package_CoreEquipmentProfile
# 308  #ThermalGeneratingUnit.CAESPlant                                                     added  #Package_CoreEquipmentProfile
# 317  #ThermalGeneratingUnit.CogenerationPlant                                             added  #Package_CoreEquipmentProfile
# 326  #ThermalGeneratingUnit.CombinedCyclePlant                                            added  #Package_CoreEquipmentProfile
# 335  #PowerElectronicsConnection.PowerElectronicsUnit                                     added  #Package_CoreEquipmentProfile
# 344  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#SolarGeneratingUnit.SolarPowerPlant  added  #Package_CoreEquipmentProfile
# 354  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#WindGeneratingUnit.WindPowerPlant    added  #Package_CoreEquipmentProfile
# 364  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint.Location               added  #Package_GeographicalLocationProfile
# 374  #SvSwitch.Switch                                                                     added  #Package_StateVariablesProfile
# 383  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint.TopologicalNode        added  #Package_TopologyProfile
# 393  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint.TopologicalNode        added  #Package_TopologyBoundaryProfile

# %%
report_name = "Property"

markdown_print("# {}".format(report_name))

properties = {}
for data in data_set:
    
    # Here goes query
    properties[data] = pandas.DataFrame(data_set[data][~data_set[data].ID.str.contains("Version")].query("VALUE == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property'").ID.unique())

#for profiles
diff = properties["new"].merge(properties["old"], how="outer", indicator="diff").replace({'left_only': r'added', 'right_only': 'removed'}).rename(columns={0:report_name})

markdown_print("## Summary")
display(diff["diff"].value_counts())

markdown_print("## Removed")
removed = diff.query("diff=='removed'")
display(removed.merge(data_set["old"], left_on=report_name, right_on="ID")[[report_name, "diff", "INSTANCE_ID"]].drop_duplicates())

markdown_print("## Added")
added = diff.query("diff=='added'")
display(added.merge(data_set["new"], left_on=report_name, right_on="ID")[[report_name, "diff", "INSTANCE_ID"]].drop_duplicates())
# Out:
# # Property
# ## Summary
# both       3374
# added      323
# removed    152
# Name: diff, dtype: int64
# ## Removed
#                                                                           Property     diff                            INSTANCE_ID
# 0     #ActivePowerPerCurrentFlow.denominatorMultiplier                              removed  #Package_EquipmentProfile
# 32    #ActivePowerPerCurrentFlow.denominatorUnit                                    removed  #Package_EquipmentProfile
# 64    #DCSeriesDevice.ratedUdc                                                      removed  #Package_EquipmentProfile
# 96    #DCShunt.ratedUdc                                                             removed  #Package_EquipmentProfile
# 128   #PerLengthDCLineParameter.capacitance                                         removed  #Package_EquipmentProfile
# 160   #CapacitancePerLength.value                                                   removed  #Package_EquipmentProfile
# 188   #CapacitancePerLength.unit                                                    removed  #Package_EquipmentProfile
# 220   #CapacitancePerLength.multiplier                                              removed  #Package_EquipmentProfile
# 252   #CapacitancePerLength.denominatorUnit                                         removed  #Package_EquipmentProfile
# 284   #CapacitancePerLength.denominatorMultiplier                                   removed  #Package_EquipmentProfile
# 316   #PerLengthDCLineParameter.inductance                                          removed  #Package_EquipmentProfile
# 348   #InductancePerLength.value                                                    removed  #Package_EquipmentProfile
# 376   #InductancePerLength.unit                                                     removed  #Package_EquipmentProfile
# 408   #InductancePerLength.multiplier                                               removed  #Package_EquipmentProfile
# 440   #InductancePerLength.denominatorUnit                                          removed  #Package_EquipmentProfile
# 472   #InductancePerLength.denominatorMultiplier                                    removed  #Package_EquipmentProfile
# 504   #PerLengthDCLineParameter.resistance                                          removed  #Package_EquipmentProfile
# 536   #ResistancePerLength.value                                                    removed  #Package_EquipmentProfile
# 564   #ResistancePerLength.unit                                                     removed  #Package_EquipmentProfile
# 596   #ResistancePerLength.multiplier                                               removed  #Package_EquipmentProfile
# 628   #ResistancePerLength.denominatorUnit                                          removed  #Package_EquipmentProfile
# 660   #ResistancePerLength.denominatorMultiplier                                    removed  #Package_EquipmentProfile
# 692   #Simple_Float.value                                                           removed  #Package_EquipmentProfile
# 699   #Simple_Float.value                                                           removed  #Package_StateVariablesProfile
# 706   #Simple_Float.value                                                           removed  #Package_SteadyStateHypothesisProfile
# 713   #Simple_Float.value                                                           removed  #Package_DiagramLayoutProfile
# 720   #Simple_Float.value                                                           removed  #Package_DynamicsProfile
# 755   #VsConverter.maxValveCurrent                                                  removed  #Package_EquipmentProfile
# 787   #GeneratingUnit.initialP                                                      removed  #Package_EquipmentProfile
# 819   #IdentifiedObject.energyIdentCodeEic                                          removed  #Package_EquipmentProfile
# 855   #IdentifiedObject.shortName                                                   removed  #Package_EquipmentProfile
# 891   #OperationalLimitType.limitType                                               removed  #Package_EquipmentProfile
# 927   #RotationSpeed.denominatorUnit                                                removed  #Package_EquipmentProfile
# 959   #RotationSpeed.denominatorMultiplier                                          removed  #Package_EquipmentProfile
# 991   #ActivePowerPerFrequency.denominatorMultiplier                                removed  #Package_EquipmentProfile
# 1023  #ActivePowerPerFrequency.denominatorUnit                                      removed  #Package_EquipmentProfile
# 1055  #RatioTapChanger.tculControlMode                                              removed  #Package_EquipmentProfile
# 1087  #ShuntCompensator.switchOnCount                                               removed  #Package_EquipmentProfile
# 1119  #ShuntCompensator.switchOnDate                                                removed  #Package_EquipmentProfile
# 1151  #VoltagePerReactivePower.denominatorMultiplier                                removed  #Package_EquipmentProfile
# 1183  #VoltagePerReactivePower.denominatorUnit                                      removed  #Package_EquipmentProfile
# 1215  #CoordinateSystem.Location                                                    removed  #Package_GeographicalLocationProfile
# 1225  #VsConverter.uf                                                               removed  #Package_StateVariablesProfile
# 1233  http://entsoe.eu/CIM/SchemaExtension/3/1#IdentifiedObject.energyIdentCodeEic  removed  #Package_TopologyBoundaryProfile
# 1242  http://entsoe.eu/CIM/SchemaExtension/3/1#IdentifiedObject.energyIdentCodeEic  removed  #Package_TopologyProfile
# 1251  http://entsoe.eu/CIM/SchemaExtension/3/1#IdentifiedObject.energyIdentCodeEic  removed  #Package_EquipmentBoundaryProfile
# 1260  http://entsoe.eu/CIM/SchemaExtension/3/1#IdentifiedObject.shortName           removed  #Package_TopologyBoundaryProfile
# 1269  http://entsoe.eu/CIM/SchemaExtension/3/1#IdentifiedObject.shortName           removed  #Package_TopologyProfile
# 1278  http://entsoe.eu/CIM/SchemaExtension/3/1#IdentifiedObject.shortName           removed  #Package_EquipmentBoundaryProfile
# 1287  http://entsoe.eu/CIM/SchemaExtension/3/1#TopologicalNode.boundaryPoint        removed  #Package_TopologyBoundaryProfile
# 1296  http://entsoe.eu/CIM/SchemaExtension/3/1#TopologicalNode.fromEndIsoCode       removed  #Package_TopologyBoundaryProfile
# 1305  http://entsoe.eu/CIM/SchemaExtension/3/1#TopologicalNode.fromEndName          removed  #Package_TopologyBoundaryProfile
# 1314  http://entsoe.eu/CIM/SchemaExtension/3/1#TopologicalNode.fromEndNameTso       removed  #Package_TopologyBoundaryProfile
# 1323  http://entsoe.eu/CIM/SchemaExtension/3/1#TopologicalNode.toEndIsoCode         removed  #Package_TopologyBoundaryProfile
# 1332  http://entsoe.eu/CIM/SchemaExtension/3/1#TopologicalNode.toEndName            removed  #Package_TopologyBoundaryProfile
# 1341  http://entsoe.eu/CIM/SchemaExtension/3/1#TopologicalNode.toEndNameTso         removed  #Package_TopologyBoundaryProfile
# 1350  #WindTurbineType3or4Dynamics.EnergySource                                     removed  #Package_DynamicsProfile
# 1368  #EnergySource.WindTurbineType3or4Dynamics                                     removed  #Package_DynamicsProfile
# 1388  #SynchronousMachineDetailed.ifdBaseValue                                      removed  #Package_DynamicsProfile
# 1404  #GovGAST4.tv                                                                  removed  #Package_DynamicsProfile
# 1420  #GovHydro4.qn1                                                                removed  #Package_DynamicsProfile
# 1436  #VolumeFlowRate.denominatorMultiplier                                         removed  #Package_DynamicsProfile
# 1452  #VolumeFlowRate.denominatorUnit                                               removed  #Package_DynamicsProfile
# 1468  #GovSteamEU.kwcor                                                             removed  #Package_DynamicsProfile
# 1484  #GovSteamFV2.ti                                                               removed  #Package_DynamicsProfile
# 1500  #ExcDC1A.edfmax                                                               removed  #Package_DynamicsProfile
# 1516  #ExcDC3A.edfmax                                                               removed  #Package_DynamicsProfile
# 1532  #PssIEEE3B.inputSignal1Type                                                   removed  #Package_DynamicsProfile
# 1548  #PssIEEE3B.inputSignal2Type                                                   removed  #Package_DynamicsProfile
# 1564  #Pss1.kw                                                                      removed  #Package_DynamicsProfile
# 1580  #Pss2B.inputSignal1Type                                                       removed  #Package_DynamicsProfile
# 1596  #Pss2B.inputSignal2Type                                                       removed  #Package_DynamicsProfile
# 1612  #Pss5.pmm                                                                     removed  #Package_DynamicsProfile
# 1628  #WindAeroConstIEC.WindGenTurbineType1IEC                                      removed  #Package_DynamicsProfile
# 1646  #WindGenTurbineType1IEC.WindAeroConstIEC                                      removed  #Package_DynamicsProfile
# 1666  #WindAeroLinearIEC.dpomega                                                    removed  #Package_DynamicsProfile
# 1682  #WindAeroLinearIEC.dptheta                                                    removed  #Package_DynamicsProfile
# 1698  #WindAeroLinearIEC.omegazero                                                  removed  #Package_DynamicsProfile
# 1714  #WindAeroLinearIEC.pavail                                                     removed  #Package_DynamicsProfile
# 1730  #WindAeroLinearIEC.thetazero                                                  removed  #Package_DynamicsProfile
# 1746  #WindAeroLinearIEC.WindGenTurbineType3IEC                                     removed  #Package_DynamicsProfile
# 1764  #WindGenTurbineType3IEC.WindAeroLinearIEC                                     removed  #Package_DynamicsProfile
# 1784  #WindContCurrLimIEC.tufilt                                                    removed  #Package_DynamicsProfile
# 1800  #WindContPitchAngleIEC.WindGenTurbineType3IEC                                 removed  #Package_DynamicsProfile
# 1818  #WindGenTurbineType3IEC.WindContPitchAngleIEC                                 removed  #Package_DynamicsProfile
# 1838  #WindContPType3IEC.dtrisemaxlvrt                                              removed  #Package_DynamicsProfile
# 1854  #WindContPType3IEC.mplvrt                                                     removed  #Package_DynamicsProfile
# 1870  #WindContPType3IEC.rramp                                                      removed  #Package_DynamicsProfile
# 1886  #WindContPType3IEC.temin                                                      removed  #Package_DynamicsProfile
# 1902  #WindContPType3IEC.tomegafilt                                                 removed  #Package_DynamicsProfile
# 1918  #WindContPType3IEC.tpfilt                                                     removed  #Package_DynamicsProfile
# 1934  #WindContPType3IEC.tufilt                                                     removed  #Package_DynamicsProfile
# 1950  #WindContPType3IEC.tuscale                                                    removed  #Package_DynamicsProfile
# 1966  #WindContPType3IEC.twref                                                      removed  #Package_DynamicsProfile
# 1982  #WindContPType3IEC.wdtd                                                       removed  #Package_DynamicsProfile
# 1998  #WindContPType3IEC.WindGenTurbineType3IEC                                     removed  #Package_DynamicsProfile
# 2016  #WindGenTurbineType3IEC.WindContPType3IEC                                     removed  #Package_DynamicsProfile
# 2036  #WindContPType4aIEC.dpmax                                                     removed  #Package_DynamicsProfile
# 2052  #WindContPType4aIEC.tpord                                                     removed  #Package_DynamicsProfile
# 2068  #WindContPType4aIEC.tufilt                                                    removed  #Package_DynamicsProfile
# 2084  #WindContPType4bIEC.dpmax                                                     removed  #Package_DynamicsProfile
# 2100  #WindContPType4bIEC.tpord                                                     removed  #Package_DynamicsProfile
# 2116  #WindContPType4bIEC.tufilt                                                    removed  #Package_DynamicsProfile
# 2132  #WindContQIEC.qmax                                                            removed  #Package_DynamicsProfile
# 2148  #WindContQIEC.qmin                                                            removed  #Package_DynamicsProfile
# 2164  #WindContQIEC.tiq                                                             removed  #Package_DynamicsProfile
# 2180  #WindContQIEC.tpfilt                                                          removed  #Package_DynamicsProfile
# 2196  #WindContQIEC.tufilt                                                          removed  #Package_DynamicsProfile
# 2212  #WindContQIEC.windLVRTQcontrolModesType                                       removed  #Package_DynamicsProfile
# 2228  #WindContRotorRIEC.tomegafilt                                                 removed  #Package_DynamicsProfile
# 2244  #WindContRotorRIEC.tpfilt                                                     removed  #Package_DynamicsProfile
# 2260  #WindPitchContEmulIEC.WindGenTurbineType2IEC                                  removed  #Package_DynamicsProfile
# 2278  #WindGenTurbineType2IEC.WindPitchContEmulIEC                                  removed  #Package_DynamicsProfile
# 2298  #WindGenTurbineType3aIEC.kpc                                                  removed  #Package_DynamicsProfile
# 2314  #WindGenTurbineType3aIEC.xs                                                   removed  #Package_DynamicsProfile
# 2330  #WindGenTurbineType3aIEC.tic                                                  removed  #Package_DynamicsProfile
# 2346  #WindGenTurbineType3bIEC.fducw                                                removed  #Package_DynamicsProfile
# 2362  #WindGenTurbineType3bIEC.tg                                                   removed  #Package_DynamicsProfile
# 2378  #WindGenTurbineType3bIEC.two                                                  removed  #Package_DynamicsProfile
# 2394  #WindGenTurbineType3bIEC.mwtcwp                                               removed  #Package_DynamicsProfile
# 2410  #WindGenTurbineType3bIEC.xs                                                   removed  #Package_DynamicsProfile
# 2426  #WindGenTurbineType3IEC.dipmax                                                removed  #Package_DynamicsProfile
# 2442  #WindGenTurbineType3IEC.diqmax                                                removed  #Package_DynamicsProfile
# 2458  #WindMechIEC.WindGenTurbineType3IEC                                           removed  #Package_DynamicsProfile
# 2476  #WindGenTurbineType3IEC.WindMechIEC                                           removed  #Package_DynamicsProfile
# 2496  #WindPitchContEmulIEC.kdroop                                                  removed  #Package_DynamicsProfile
# 2512  #WindPitchContEmulIEC.kipce                                                   removed  #Package_DynamicsProfile
# 2528  #WindPitchContEmulIEC.komegaaero                                              removed  #Package_DynamicsProfile
# 2544  #WindPitchContEmulIEC.kppce                                                   removed  #Package_DynamicsProfile
# 2560  #WindPitchContEmulIEC.omegaref                                                removed  #Package_DynamicsProfile
# 2576  #WindPitchContEmulIEC.pimax                                                   removed  #Package_DynamicsProfile
# 2592  #WindPitchContEmulIEC.pimin                                                   removed  #Package_DynamicsProfile
# 2608  #WindPitchContEmulIEC.t1                                                      removed  #Package_DynamicsProfile
# 2624  #WindPitchContEmulIEC.t2                                                      removed  #Package_DynamicsProfile
# 2640  #WindPitchContEmulIEC.tpe                                                     removed  #Package_DynamicsProfile
# 2656  #WindPlantFreqPcontrolIEC.twpffilt                                            removed  #Package_DynamicsProfile
# 2672  #WindPlantFreqPcontrolIEC.twppfilt                                            removed  #Package_DynamicsProfile
# 2688  #WindPlantReactiveControlIEC.mwppf                                            removed  #Package_DynamicsProfile
# 2704  #WindPlantReactiveControlIEC.mwpu                                             removed  #Package_DynamicsProfile
# 2720  #WindPlantReactiveControlIEC.twppfilt                                         removed  #Package_DynamicsProfile
# 2736  #WindPlantReactiveControlIEC.twpqfilt                                         removed  #Package_DynamicsProfile
# 2752  #WindPlantReactiveControlIEC.twpufilt                                         removed  #Package_DynamicsProfile
# 2768  #WindProtectionIEC.tfover                                                     removed  #Package_DynamicsProfile
# 2784  #WindProtectionIEC.tfunder                                                    removed  #Package_DynamicsProfile
# 2800  #WindProtectionIEC.tuover                                                     removed  #Package_DynamicsProfile
# 2816  #WindProtectionIEC.tuunder                                                    removed  #Package_DynamicsProfile
# 2832  #LoadComposite.lfrac                                                          removed  #Package_DynamicsProfile
# 2848  #LoadGenericNonLinear.pt                                                      removed  #Package_DynamicsProfile
# 2864  #LoadGenericNonLinear.qt                                                      removed  #Package_DynamicsProfile
# 2880  http://entsoe.eu/CIM/SchemaExtension/3/1#ConnectivityNode.boundaryPoint       removed  #Package_EquipmentBoundaryProfile
# 2889  http://entsoe.eu/CIM/SchemaExtension/3/1#ConnectivityNode.fromEndIsoCode      removed  #Package_EquipmentBoundaryProfile
# 2898  http://entsoe.eu/CIM/SchemaExtension/3/1#ConnectivityNode.fromEndName         removed  #Package_EquipmentBoundaryProfile
# 2907  http://entsoe.eu/CIM/SchemaExtension/3/1#ConnectivityNode.fromEndNameTso      removed  #Package_EquipmentBoundaryProfile
# 2916  http://entsoe.eu/CIM/SchemaExtension/3/1#ConnectivityNode.toEndIsoCode        removed  #Package_EquipmentBoundaryProfile
# 2925  http://entsoe.eu/CIM/SchemaExtension/3/1#ConnectivityNode.toEndName           removed  #Package_EquipmentBoundaryProfile
# 2934  http://entsoe.eu/CIM/SchemaExtension/3/1#ConnectivityNode.toEndNameTso        removed  #Package_EquipmentBoundaryProfile
# 2943  http://entsoe.eu/CIM/SchemaExtension/3/1#EnergySchedulingType.EnergySource    removed  #Package_EquipmentBoundaryProfile
# 2952  http://entsoe.eu/CIM/SchemaExtension/3/1#EnergySource.EnergySchedulingType    removed  #Package_EquipmentBoundaryProfile
# 2962  #PerLengthDCLineParameter.DCLineSegments                                      removed  #Package_EquipmentProfile
# 2980  #DCLineSegment.PerLengthParameter                                             removed  #Package_EquipmentProfile
# ## Added
#                                                                                          Property   diff                            INSTANCE_ID
# 0     #WindTurbineType3or4Dynamics.PowerElectronicsConnection                                      added  #Package_DynamicsProfile
# 9     #PowerElectronicsConnection.WindTurbineType3or4Dynamics                                      added  #Package_DynamicsProfile
# 18    #StaticVarCompensatorDynamics.StaticVarCompensator                                           added  #Package_DynamicsProfile
# 27    #StaticVarCompensator.StaticVarCompensatorDynamics                                           added  #Package_DynamicsProfile
# 36    #CSCDynamics.CSConverter                                                                     added  #Package_DynamicsProfile
# 45    #CsConverter.CSCDynamics                                                                     added  #Package_DynamicsProfile
# 54    #VSCDynamics.VsConverter                                                                     added  #Package_DynamicsProfile
# 63    #VsConverter.VSCDynamics                                                                     added  #Package_DynamicsProfile
# 72    #CSCUserDefined.proprietary                                                                  added  #Package_DynamicsProfile
# 80    #CSCUserDefined.ProprietaryParameterDynamics                                                 added  #Package_DynamicsProfile
# 89    #ProprietaryParameterDynamics.CSCUserDefined                                                 added  #Package_DynamicsProfile
# 98    #SVCUserDefined.proprietary                                                                  added  #Package_DynamicsProfile
# 106   #SVCUserDefined.ProprietaryParameterDynamics                                                 added  #Package_DynamicsProfile
# 115   #ProprietaryParameterDynamics.SVCUserDefined                                                 added  #Package_DynamicsProfile
# 124   #VSCUserDefined.proprietary                                                                  added  #Package_DynamicsProfile
# 132   #VSCUserDefined.ProprietaryParameterDynamics                                                 added  #Package_DynamicsProfile
# 141   #ProprietaryParameterDynamics.VSCUserDefined                                                 added  #Package_DynamicsProfile
# 150   #CrossCompoundTurbineGovernorDynamics.HighPressureSynchronousMachineDynamics                 added  #Package_DynamicsProfile
# 159   #SynchronousMachineDynamics.CrossCompoundTurbineGovernorDyanmics                             added  #Package_DynamicsProfile
# 168   #CrossCompoundTurbineGovernorDynamics.LowPressureSynchronousMachineDynamics                  added  #Package_DynamicsProfile
# 177   #SynchronousMachineDynamics.CrossCompoundTurbineGovernorDynamics                             added  #Package_DynamicsProfile
# 186   #GovGAST4.ty                                                                                 added  #Package_DynamicsProfile
# 194   #GovHydro4.qnl                                                                               added  #Package_DynamicsProfile
# 202   #GovHydro4.model                                                                             added  #Package_DynamicsProfile
# 210   #GovSteamBB.fcut                                                                             added  #Package_DynamicsProfile
# 218   #GovSteamBB.ks                                                                               added  #Package_DynamicsProfile
# 226   #GovSteamBB.kls                                                                              added  #Package_DynamicsProfile
# 234   #GovSteamBB.kg                                                                               added  #Package_DynamicsProfile
# 242   #GovSteamBB.t1                                                                               added  #Package_DynamicsProfile
# 250   #GovSteamBB.kp                                                                               added  #Package_DynamicsProfile
# 258   #GovSteamBB.tn                                                                               added  #Package_DynamicsProfile
# 266   #GovSteamBB.kd                                                                               added  #Package_DynamicsProfile
# 274   #GovSteamBB.td                                                                               added  #Package_DynamicsProfile
# 282   #GovSteamBB.pmax                                                                             added  #Package_DynamicsProfile
# 290   #GovSteamBB.pmin                                                                             added  #Package_DynamicsProfile
# 298   #GovSteamBB.t4                                                                               added  #Package_DynamicsProfile
# 306   #GovSteamBB.k2                                                                               added  #Package_DynamicsProfile
# 314   #GovSteamBB.t5                                                                               added  #Package_DynamicsProfile
# 322   #GovSteamBB.k3                                                                               added  #Package_DynamicsProfile
# 330   #GovSteamBB.t6                                                                               added  #Package_DynamicsProfile
# 338   #GovSteamBB.peflag                                                                           added  #Package_DynamicsProfile
# 346   #GovSteamEU.komegacor                                                                        added  #Package_DynamicsProfile
# 354   #GovSteamFV3.gv1                                                                             added  #Package_DynamicsProfile
# 362   #GovSteamFV3.pgv1                                                                            added  #Package_DynamicsProfile
# 370   #GovSteamFV3.gv2                                                                             added  #Package_DynamicsProfile
# 378   #GovSteamFV3.pgv2                                                                            added  #Package_DynamicsProfile
# 386   #GovSteamFV3.gv3                                                                             added  #Package_DynamicsProfile
# 394   #GovSteamFV3.pgv3                                                                            added  #Package_DynamicsProfile
# 402   #GovSteamFV3.gv4                                                                             added  #Package_DynamicsProfile
# 410   #GovSteamFV3.pgv4                                                                            added  #Package_DynamicsProfile
# 418   #GovSteamFV3.gv5                                                                             added  #Package_DynamicsProfile
# 426   #GovSteamFV3.pgv5                                                                            added  #Package_DynamicsProfile
# 434   #GovSteamFV3.gv6                                                                             added  #Package_DynamicsProfile
# 442   #GovSteamFV3.pgv6                                                                            added  #Package_DynamicsProfile
# 450   #ExcDC1A.efdmax                                                                              added  #Package_DynamicsProfile
# 458   #ExcDC3A.efdmax                                                                              added  #Package_DynamicsProfile
# 466   #ExcNI.busFedSelector                                                                        added  #Package_DynamicsProfile
# 474   #ExcNI.tr                                                                                    added  #Package_DynamicsProfile
# 482   #ExcNI.ka                                                                                    added  #Package_DynamicsProfile
# 490   #ExcNI.ta                                                                                    added  #Package_DynamicsProfile
# 498   #ExcNI.vrmax                                                                                 added  #Package_DynamicsProfile
# 506   #ExcNI.vrmin                                                                                 added  #Package_DynamicsProfile
# 514   #ExcNI.kf                                                                                    added  #Package_DynamicsProfile
# 522   #ExcNI.tf2                                                                                   added  #Package_DynamicsProfile
# 530   #ExcNI.tf1                                                                                   added  #Package_DynamicsProfile
# 538   #ExcNI.r                                                                                     added  #Package_DynamicsProfile
# 546   #ExcRQB.ki0                                                                                  added  #Package_DynamicsProfile
# 554   #ExcRQB.ki1                                                                                  added  #Package_DynamicsProfile
# 562   #ExcRQB.te                                                                                   added  #Package_DynamicsProfile
# 570   #ExcRQB.tc                                                                                   added  #Package_DynamicsProfile
# 578   #ExcRQB.klir                                                                                 added  #Package_DynamicsProfile
# 586   #ExcRQB.ucmin                                                                                added  #Package_DynamicsProfile
# 594   #ExcRQB.ucmax                                                                                added  #Package_DynamicsProfile
# 602   #ExcRQB.lus                                                                                  added  #Package_DynamicsProfile
# 610   #ExcRQB.klus                                                                                 added  #Package_DynamicsProfile
# 618   #ExcRQB.mesu                                                                                 added  #Package_DynamicsProfile
# 626   #ExcRQB.t4m                                                                                  added  #Package_DynamicsProfile
# 634   #ExcRQB.lsat                                                                                 added  #Package_DynamicsProfile
# 642   #ExcRQB.tf                                                                                   added  #Package_DynamicsProfile
# 650   #Pss1.komega                                                                                 added  #Package_DynamicsProfile
# 658   #Pss5.pmin                                                                                   added  #Package_DynamicsProfile
# 666   #PssRQB.ki2                                                                                  added  #Package_DynamicsProfile
# 674   #PssRQB.ki3                                                                                  added  #Package_DynamicsProfile
# 682   #PssRQB.ki4                                                                                  added  #Package_DynamicsProfile
# 690   #PssRQB.t4m                                                                                  added  #Package_DynamicsProfile
# 698   #PssRQB.tomd                                                                                 added  #Package_DynamicsProfile
# 706   #PssRQB.tomsl                                                                                added  #Package_DynamicsProfile
# 714   #PssRQB.t4mom                                                                                added  #Package_DynamicsProfile
# 722   #PssRQB.sibv                                                                                 added  #Package_DynamicsProfile
# 730   #PssRQB.kdpm                                                                                 added  #Package_DynamicsProfile
# 738   #PssRQB.t4f                                                                                  added  #Package_DynamicsProfile
# 746   #PssSTAB2A.k2                                                                                added  #Package_DynamicsProfile
# 754   #PssSTAB2A.k3                                                                                added  #Package_DynamicsProfile
# 762   #PssSTAB2A.k4                                                                                added  #Package_DynamicsProfile
# 770   #PssSTAB2A.k5                                                                                added  #Package_DynamicsProfile
# 778   #PssSTAB2A.t2                                                                                added  #Package_DynamicsProfile
# 786   #PssSTAB2A.t3                                                                                added  #Package_DynamicsProfile
# 794   #PssSTAB2A.t5                                                                                added  #Package_DynamicsProfile
# 802   #PssSTAB2A.hlim                                                                              added  #Package_DynamicsProfile
# 810   #WindGenTurbineType1aIEC.WindAeroConstIEC                                                    added  #Package_DynamicsProfile
# 819   #WindAeroConstIEC.WindGenTurbineType1aIEC                                                    added  #Package_DynamicsProfile
# 828   #WindAeroOneDimIEC.ka                                                                        added  #Package_DynamicsProfile
# 836   #WindAeroOneDimIEC.thetaomega                                                                added  #Package_DynamicsProfile
# 844   #WindTurbineType3IEC.WindAeroOneDimIEC                                                       added  #Package_DynamicsProfile
# 853   #WindAeroOneDimIEC.WindTurbineType3IEC                                                       added  #Package_DynamicsProfile
# 862   #WindAeroTwoDimIEC.dpomega                                                                   added  #Package_DynamicsProfile
# 870   #WindAeroTwoDimIEC.dptheta                                                                   added  #Package_DynamicsProfile
# 878   #WindAeroTwoDimIEC.dpv1                                                                      added  #Package_DynamicsProfile
# 886   #WindAeroTwoDimIEC.omegazero                                                                 added  #Package_DynamicsProfile
# 894   #WindAeroTwoDimIEC.pavail                                                                    added  #Package_DynamicsProfile
# 902   #WindAeroTwoDimIEC.thetazero                                                                 added  #Package_DynamicsProfile
# 910   #WindAeroTwoDimIEC.thetav2                                                                   added  #Package_DynamicsProfile
# 918   #WindTurbineType3IEC.WindAeroTwoDimIEC                                                       added  #Package_DynamicsProfile
# 927   #WindAeroTwoDimIEC.WindTurbineType3IEC                                                       added  #Package_DynamicsProfile
# 936   #WindContCurrLimIEC.kpqu                                                                     added  #Package_DynamicsProfile
# 944   #WindContCurrLimIEC.tufiltcl                                                                 added  #Package_DynamicsProfile
# 952   #WindContCurrLimIEC.upqumax                                                                  added  #Package_DynamicsProfile
# 960   #WindTurbineType3IEC.WindContPitchAngleIEC                                                   added  #Package_DynamicsProfile
# 969   #WindContPitchAngleIEC.WindTurbineType3IEC                                                   added  #Package_DynamicsProfile
# 978   #WindContPType3IEC.dprefmax                                                                  added  #Package_DynamicsProfile
# 986   #WindContPType3IEC.dprefmin                                                                  added  #Package_DynamicsProfile
# 994   #WindContPType3IEC.dthetamax                                                                 added  #Package_DynamicsProfile
# 1002  #WindContPType3IEC.dthetamaxuvrt                                                             added  #Package_DynamicsProfile
# 1010  #WindContPType3IEC.mpuvrt                                                                    added  #Package_DynamicsProfile
# 1018  #WindContPType3IEC.thetaemin                                                                 added  #Package_DynamicsProfile
# 1026  #WindContPType3IEC.thetauscale                                                               added  #Package_DynamicsProfile
# 1034  #WindContPType3IEC.tomegafiltp3                                                              added  #Package_DynamicsProfile
# 1042  #WindContPType3IEC.tpfiltp3                                                                  added  #Package_DynamicsProfile
# 1050  #WindContPType3IEC.tufiltp3                                                                  added  #Package_DynamicsProfile
# 1058  #WindContPType3IEC.tomegaref                                                                 added  #Package_DynamicsProfile
# 1066  #WindContPType3IEC.omegadtd                                                                  added  #Package_DynamicsProfile
# 1074  #WindTurbineType3IEC.WindContPType3IEC                                                       added  #Package_DynamicsProfile
# 1083  #WindContPType3IEC.WindTurbineType3IEC                                                       added  #Package_DynamicsProfile
# 1092  #WindContPType4aIEC.dpmaxp4a                                                                 added  #Package_DynamicsProfile
# 1100  #WindContPType4aIEC.tpordp4a                                                                 added  #Package_DynamicsProfile
# 1108  #WindContPType4aIEC.tufiltp4a                                                                added  #Package_DynamicsProfile
# 1116  #WindContPType4bIEC.dpmaxp4b                                                                 added  #Package_DynamicsProfile
# 1124  #WindContPType4bIEC.tpordp4b                                                                 added  #Package_DynamicsProfile
# 1132  #WindContPType4bIEC.tufiltp4b                                                                added  #Package_DynamicsProfile
# 1140  #WindContQIEC.tpfiltq                                                                        added  #Package_DynamicsProfile
# 1148  #WindContQIEC.tufiltq                                                                        added  #Package_DynamicsProfile
# 1156  #WindContQIEC.windUVRTQcontrolModesType                                                      added  #Package_DynamicsProfile
# 1164  #WindContQLimIEC.qmax                                                                        added  #Package_DynamicsProfile
# 1172  #WindContQLimIEC.qmin                                                                        added  #Package_DynamicsProfile
# 1180  #WindContQLimIEC.WindTurbineType3or4IEC                                                      added  #Package_DynamicsProfile
# 1189  #WindTurbineType3or4IEC.WindContQLimIEC                                                      added  #Package_DynamicsProfile
# 1198  #WindContQPQULimIEC.tpfiltql                                                                 added  #Package_DynamicsProfile
# 1206  #WindContQPQULimIEC.tufiltql                                                                 added  #Package_DynamicsProfile
# 1214  #WindContQPQULimIEC.WindTurbineType3or4IEC                                                   added  #Package_DynamicsProfile
# 1223  #WindTurbineType3or4IEC.WindContQPQULimIEC                                                   added  #Package_DynamicsProfile
# 1232  #WindContQPQULimIEC.WindDynamicsLookupTable                                                  added  #Package_DynamicsProfile
# 1241  #WindDynamicsLookupTable.WindContQPQULimIEC                                                  added  #Package_DynamicsProfile
# 1250  #WindContRotorRIEC.tomegafiltrr                                                              added  #Package_DynamicsProfile
# 1258  #WindContRotorRIEC.tpfiltrr                                                                  added  #Package_DynamicsProfile
# 1266  #WindProtectionIEC.WindDynamicsLookupTable                                                   added  #Package_DynamicsProfile
# 1275  #WindDynamicsLookupTable.WindProtectionIEC                                                   added  #Package_DynamicsProfile
# 1284  #WindPlantReactiveControlIEC.WindDynamicsLookupTable                                         added  #Package_DynamicsProfile
# 1293  #WindDynamicsLookupTable.WindPlantReactiveControlIEC                                         added  #Package_DynamicsProfile
# 1302  #WindGenType3bIEC.WindDynamicsLookupTable                                                    added  #Package_DynamicsProfile
# 1311  #WindDynamicsLookupTable.WindGenType3bIEC                                                    added  #Package_DynamicsProfile
# 1320  #WindDynamicsLookupTable.WindPitchContPowerIEC                                               added  #Package_DynamicsProfile
# 1329  #WindPitchContPowerIEC.WindDynamicsLookupTable                                               added  #Package_DynamicsProfile
# 1338  #WindPitchContPowerIEC.WindGenTurbineType1bIEC                                               added  #Package_DynamicsProfile
# 1347  #WindGenTurbineType1bIEC.WindPitchContPowerIEC                                               added  #Package_DynamicsProfile
# 1356  #WindPitchContPowerIEC.WindGenTurbineType2IEC                                                added  #Package_DynamicsProfile
# 1365  #WindGenTurbineType2IEC.WindPitchContPowerIEC                                                added  #Package_DynamicsProfile
# 1374  #WindGenType3aIEC.kpc                                                                        added  #Package_DynamicsProfile
# 1382  #WindGenType3aIEC.tic                                                                        added  #Package_DynamicsProfile
# 1390  #WindGenType3aIEC.WindTurbineType4IEC                                                        added  #Package_DynamicsProfile
# 1399  #WindTurbineType4IEC.WindGenType3aIEC                                                        added  #Package_DynamicsProfile
# 1408  #WindGenType3bIEC.mwtcwp                                                                     added  #Package_DynamicsProfile
# 1416  #WindGenType3bIEC.tg                                                                         added  #Package_DynamicsProfile
# 1424  #WindGenType3bIEC.two                                                                        added  #Package_DynamicsProfile
# 1432  #WindGenType3IEC.dipmax                                                                      added  #Package_DynamicsProfile
# 1440  #WindGenType3IEC.diqmax                                                                      added  #Package_DynamicsProfile
# 1448  #WindGenType3IEC.xs                                                                          added  #Package_DynamicsProfile
# 1456  #WindGenType3IEC.WindTurbineType3IEC                                                         added  #Package_DynamicsProfile
# 1465  #WindTurbineType3IEC.WindGenType3IEC                                                         added  #Package_DynamicsProfile
# 1474  #WindGenType4IEC.WindTurbineType4aIEC                                                        added  #Package_DynamicsProfile
# 1483  #WindTurbineType4aIEC.WindGenType4IEC                                                        added  #Package_DynamicsProfile
# 1492  #WindGenType4IEC.WindTurbineType4bIEC                                                        added  #Package_DynamicsProfile
# 1501  #WindTurbineType4bIEC.WindGenType4IEC                                                        added  #Package_DynamicsProfile
# 1510  #WindTurbineType3IEC.WindMechIEC                                                             added  #Package_DynamicsProfile
# 1519  #WindMechIEC.WindTurbineType3IEC                                                             added  #Package_DynamicsProfile
# 1528  #WindPitchContPowerIEC.dpmax                                                                 added  #Package_DynamicsProfile
# ...
# 1958  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#ConnectivityNode.BoundaryPoint               added  #Package_EquipmentBoundaryProfile
# 1968  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#ConnectivityNode.BoundaryPoint               added  #Package_CoreEquipmentProfile
# 1978  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.energyIdentCodeEic          added  #Package_EquipmentBoundaryProfile
# 1987  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.energyIdentCodeEic          added  #Package_CoreEquipmentProfile
# 1996  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.energyIdentCodeEic          added  #Package_OperationProfile
# 2005  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.energyIdentCodeEic          added  #Package_TopologyProfile
# 2014  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.energyIdentCodeEic          added  #Package_TopologyBoundaryProfile
# 2023  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.shortName                   added  #Package_EquipmentBoundaryProfile
# 2032  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.shortName                   added  #Package_CoreEquipmentProfile
# 2041  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.shortName                   added  #Package_OperationProfile
# 2050  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.shortName                   added  #Package_TopologyProfile
# 2059  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#IdentifiedObject.shortName                   added  #Package_TopologyBoundaryProfile
# 2068  #ACDCConverter.maxP                                                                          added  #Package_CoreEquipmentProfile
# 2076  #ACDCConverter.minP                                                                          added  #Package_CoreEquipmentProfile
# 2084  #Clamp.ACLineSegment                                                                         added  #Package_CoreEquipmentProfile
# 2093  #ACLineSegment.Clamp                                                                         added  #Package_CoreEquipmentProfile
# 2102  #Cut.ACLineSegment                                                                           added  #Package_CoreEquipmentProfile
# 2111  #ACLineSegment.Cut                                                                           added  #Package_CoreEquipmentProfile
# 2120  #ActivePowerLimit.normalValue                                                                added  #Package_CoreEquipmentProfile
# 2128  #ApparentPowerLimit.normalValue                                                              added  #Package_CoreEquipmentProfile
# 2136  #AuxiliaryEquipment.Terminal                                                                 added  #Package_CoreEquipmentProfile
# 2145  #Terminal.AuxiliaryEquipment                                                                 added  #Package_CoreEquipmentProfile
# 2154  #BatteryUnit.ratedE                                                                          added  #Package_CoreEquipmentProfile
# 2162  #RealEnergy.multiplier                                                                       added  #Package_CoreEquipmentProfile
# 2170  #RealEnergy.multiplier                                                                       added  #Package_SteadyStateHypothesisProfile
# 2178  #RealEnergy.unit                                                                             added  #Package_CoreEquipmentProfile
# 2186  #RealEnergy.unit                                                                             added  #Package_SteadyStateHypothesisProfile
# 2194  #RealEnergy.value                                                                            added  #Package_CoreEquipmentProfile
# 2201  #RealEnergy.value                                                                            added  #Package_SteadyStateHypothesisProfile
# 2208  #ThermalGeneratingUnit.CAESPlant                                                             added  #Package_CoreEquipmentProfile
# 2217  #CAESPlant.ThermalGeneratingUnit                                                             added  #Package_CoreEquipmentProfile
# 2226  #Clamp.lengthFromTerminal1                                                                   added  #Package_CoreEquipmentProfile
# 2234  #ThermalGeneratingUnit.CogenerationPlant                                                     added  #Package_CoreEquipmentProfile
# 2243  #CogenerationPlant.ThermalGeneratingUnits                                                    added  #Package_CoreEquipmentProfile
# 2252  #ThermalGeneratingUnit.CombinedCyclePlant                                                    added  #Package_CoreEquipmentProfile
# 2261  #CombinedCyclePlant.ThermalGeneratingUnits                                                   added  #Package_CoreEquipmentProfile
# 2270  #CurrentLimit.normalValue                                                                    added  #Package_CoreEquipmentProfile
# 2278  #Cut.lengthFromTerminal1                                                                     added  #Package_CoreEquipmentProfile
# 2286  #DCConductingEquipment.ratedUdc                                                              added  #Package_CoreEquipmentProfile
# 2294  #EnergySource.pMin                                                                           added  #Package_CoreEquipmentProfile
# 2302  #EnergySource.pMax                                                                           added  #Package_CoreEquipmentProfile
# 2310  #Equipment.normallyInService                                                                 added  #Package_CoreEquipmentProfile
# 2318  #GeneratingUnit.startupTime                                                                  added  #Package_CoreEquipmentProfile
# 2326  #HydroGeneratingUnit.dropHeight                                                              added  #Package_CoreEquipmentProfile
# 2334  #HydroGeneratingUnit.turbineType                                                             added  #Package_CoreEquipmentProfile
# 2342  #OperationalLimitType.isInfiniteDuration                                                     added  #Package_CoreEquipmentProfile
# 2350  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#OperationalLimitType.kind                    added  #Package_CoreEquipmentProfile
# 2359  #PowerElectronicsConnection.maxQ                                                             added  #Package_CoreEquipmentProfile
# 2367  #PowerElectronicsConnection.minQ                                                             added  #Package_CoreEquipmentProfile
# 2375  #PowerElectronicsConnection.ratedS                                                           added  #Package_CoreEquipmentProfile
# 2383  #PowerElectronicsConnection.ratedU                                                           added  #Package_CoreEquipmentProfile
# 2391  #PowerElectronicsConnection.PowerElectronicsUnit                                             added  #Package_CoreEquipmentProfile
# 2400  #PowerElectronicsUnit.PowerElectronicsConnection                                             added  #Package_CoreEquipmentProfile
# 2409  #PowerElectronicsUnit.maxP                                                                   added  #Package_CoreEquipmentProfile
# 2417  #PowerElectronicsUnit.minP                                                                   added  #Package_CoreEquipmentProfile
# 2425  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#SolarPowerPlant.SolarGeneratingUnits         added  #Package_CoreEquipmentProfile
# 2435  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#SolarGeneratingUnit.SolarPowerPlant          added  #Package_CoreEquipmentProfile
# 2445  #VoltageLimit.normalValue                                                                    added  #Package_CoreEquipmentProfile
# 2453  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#WindPowerPlant.WindGeneratingUnits           added  #Package_CoreEquipmentProfile
# 2463  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#WindGeneratingUnit.WindPowerPlant            added  #Package_CoreEquipmentProfile
# 2473  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint.Location                       added  #Package_GeographicalLocationProfile
# 2483  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#Location.BoundaryPoint                       added  #Package_GeographicalLocationProfile
# 2493  #CoordinateSystem.Locations                                                                  added  #Package_GeographicalLocationProfile
# 2502  #Location.mainAddress                                                                        added  #Package_GeographicalLocationProfile
# 2510  #StreetAddress.streetDetail                                                                  added  #Package_GeographicalLocationProfile
# 2518  #StreetDetail.number                                                                         added  #Package_GeographicalLocationProfile
# 2526  #StreetDetail.name                                                                           added  #Package_GeographicalLocationProfile
# 2534  #StreetDetail.suffix                                                                         added  #Package_GeographicalLocationProfile
# 2542  #StreetDetail.prefix                                                                         added  #Package_GeographicalLocationProfile
# 2550  #StreetDetail.type                                                                           added  #Package_GeographicalLocationProfile
# 2558  #StreetDetail.code                                                                           added  #Package_GeographicalLocationProfile
# 2566  #StreetDetail.buildingName                                                                   added  #Package_GeographicalLocationProfile
# 2574  #StreetDetail.suiteNumber                                                                    added  #Package_GeographicalLocationProfile
# 2582  #StreetDetail.addressGeneral                                                                 added  #Package_GeographicalLocationProfile
# 2590  #StreetDetail.addressGeneral2                                                                added  #Package_GeographicalLocationProfile
# 2598  #StreetDetail.addressGeneral3                                                                added  #Package_GeographicalLocationProfile
# 2606  #StreetDetail.withinTownLimits                                                               added  #Package_GeographicalLocationProfile
# 2614  #StreetDetail.floorIdentification                                                            added  #Package_GeographicalLocationProfile
# 2622  #StreetAddress.townDetail                                                                    added  #Package_GeographicalLocationProfile
# 2630  #TownDetail.code                                                                             added  #Package_GeographicalLocationProfile
# 2638  #TownDetail.section                                                                          added  #Package_GeographicalLocationProfile
# 2646  #TownDetail.name                                                                             added  #Package_GeographicalLocationProfile
# 2654  #TownDetail.stateOrProvince                                                                  added  #Package_GeographicalLocationProfile
# 2662  #TownDetail.country                                                                          added  #Package_GeographicalLocationProfile
# 2670  #StreetAddress.status                                                                        added  #Package_GeographicalLocationProfile
# 2678  #Status.value                                                                                added  #Package_GeographicalLocationProfile
# 2686  #Status.dateTime                                                                             added  #Package_GeographicalLocationProfile
# 2694  #Status.remark                                                                               added  #Package_GeographicalLocationProfile
# 2702  #Status.reason                                                                               added  #Package_GeographicalLocationProfile
# 2710  #StreetAddress.postalCode                                                                    added  #Package_GeographicalLocationProfile
# 2718  #StreetAddress.poBox                                                                         added  #Package_GeographicalLocationProfile
# 2726  #StreetAddress.language                                                                      added  #Package_GeographicalLocationProfile
# 2734  #BatteryUnit.batteryState                                                                    added  #Package_SteadyStateHypothesisProfile
# 2742  #BatteryUnit.storedE                                                                         added  #Package_SteadyStateHypothesisProfile
# 2750  #Equipment.inService                                                                         added  #Package_SteadyStateHypothesisProfile
# 2758  #PowerElectronicsConnection.p                                                                added  #Package_SteadyStateHypothesisProfile
# 2766  #PowerElectronicsConnection.q                                                                added  #Package_SteadyStateHypothesisProfile
# 2774  #RegulatingControl.maxAllowedTargetValue                                                     added  #Package_SteadyStateHypothesisProfile
# 2782  #RegulatingControl.minAllowedTargetValue                                                     added  #Package_SteadyStateHypothesisProfile
# 2790  #Switch.locked                                                                               added  #Package_SteadyStateHypothesisProfile
# 2798  #VsConverter.targetPowerFactorPcc                                                            added  #Package_SteadyStateHypothesisProfile
# 2806  #VsConverter.targetPhasePcc                                                                  added  #Package_SteadyStateHypothesisProfile
# 2814  #VsConverter.targetPWMfactor                                                                 added  #Package_SteadyStateHypothesisProfile
# 2822  #SvSwitch.open                                                                               added  #Package_StateVariablesProfile
# 2830  #SvSwitch.Switch                                                                             added  #Package_StateVariablesProfile
# 2839  #Switch.SvSwitch                                                                             added  #Package_StateVariablesProfile
# 2848  #VsConverter.uv                                                                              added  #Package_StateVariablesProfile
# 2856  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint.TopologicalNode                added  #Package_TopologyProfile
# 2866  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#BoundaryPoint.TopologicalNode                added  #Package_TopologyBoundaryProfile
# 2876  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#TopologicalNode.BoundaryPoint                added  #Package_TopologyProfile
# 2886  http://iec.ch/TC57/CIM100-EuropeanExtension/1/0#TopologicalNode.BoundaryPoint                added  #Package_TopologyBoundaryProfile

# %%
report_name = "Multiplicity"

markdown_print("# {}".format(report_name))

properties = {}
for data in data_set:
    
    # Here goes query
    property_data = data_set[data].merge(data_set[data].query("VALUE == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property'"), on="ID", suffixes=("", "_remove"))[data_set[data].columns].drop_duplicates()
    properties[data] = property_data.query("KEY=='multiplicity'")


common_property = properties["new"].merge(properties["old"], on=["ID","KEY", "INSTANCE_ID"], how="inner", suffixes=("_new", "_old"))
print("Common " + str(len(common_property)))


changes = common_property[~(common_property["VALUE_new"] == common_property["VALUE_old"])][["ID", "INSTANCE_ID", "VALUE_old", "VALUE_new"]]
print("Changes " + str(len(changes)))
display(changes)
# Out:
# # Multiplicity
# Common 2910
# Changes 59
#                                                             ID                            INSTANCE_ID                                                      VALUE_old                                                      VALUE_new
# 31    #VisibilityLayer.VisibleObjects                           #Package_DiagramLayoutProfile          http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n
# 127   #RotatingMachineDynamics.damping                          #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 128   #RotatingMachineDynamics.inertia                          #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 131   #RotatingMachineDynamics.statorLeakageReactance           #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 132   #RotatingMachineDynamics.statorResistance                 #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 195   #TurbineGovernorDynamics.SynchronousMachineDynamics       #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 201   #SynchronousMachineDetailed.efdBaseRatio                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 202   #SynchronousMachineDetailed.ifdBaseType                   #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 205   #SynchronousMachineTimeConstantReactance.ks               #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 206   #SynchronousMachineTimeConstantReactance.xDirectSync      #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 207   #SynchronousMachineTimeConstantReactance.xDirectTrans     #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 208   #SynchronousMachineTimeConstantReactance.xDirectSubtrans  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 209   #SynchronousMachineTimeConstantReactance.xQuadSync        #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 211   #SynchronousMachineTimeConstantReactance.xQuadSubtrans    #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 212   #SynchronousMachineTimeConstantReactance.tpdo             #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 213   #SynchronousMachineTimeConstantReactance.tppdo            #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 215   #SynchronousMachineTimeConstantReactance.tppqo            #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 216   #SynchronousMachineTimeConstantReactance.tc               #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 217   #SynchronousMachineEquivalentCircuit.xad                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 218   #SynchronousMachineEquivalentCircuit.rfd                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 219   #SynchronousMachineEquivalentCircuit.xfd                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 220   #SynchronousMachineEquivalentCircuit.r1d                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 221   #SynchronousMachineEquivalentCircuit.x1d                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 222   #SynchronousMachineEquivalentCircuit.xf1d                 #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 223   #SynchronousMachineEquivalentCircuit.xaq                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 224   #SynchronousMachineEquivalentCircuit.r1q                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 225   #SynchronousMachineEquivalentCircuit.x1q                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 226   #SynchronousMachineEquivalentCircuit.r2q                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 227   #SynchronousMachineEquivalentCircuit.x2q                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 234   #AsynchronousMachineTimeConstantReactance.xs              #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 235   #AsynchronousMachineTimeConstantReactance.xp              #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 236   #AsynchronousMachineTimeConstantReactance.xpp             #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 237   #AsynchronousMachineTimeConstantReactance.tpo             #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 238   #AsynchronousMachineTimeConstantReactance.tppo            #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 239   #AsynchronousMachineEquivalentCircuit.xm                  #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 240   #AsynchronousMachineEquivalentCircuit.rr1                 #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 241   #AsynchronousMachineEquivalentCircuit.xlr1                #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 242   #AsynchronousMachineEquivalentCircuit.rr2                 #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 243   #AsynchronousMachineEquivalentCircuit.xlr2                #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1
# 1125  #ExcitationSystemDynamics.VoltageCompensatorDynamics      #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1
# 2623  #WindContPType3IEC.WindDynamicsLookupTable                #Package_DynamicsProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:2..n  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n
# 2798  #Location.CoordinateSystem                                #Package_GeographicalLocationProfile   http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1
# 2801  #Location.PositionPoints                                  #Package_GeographicalLocationProfile   http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n
# 2809  #ACDCConverter.targetPpcc                                 #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2810  #ACDCConverter.targetUdc                                  #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2817  #CsConverter.targetAlpha                                  #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2818  #CsConverter.targetGamma                                  #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2819  #CsConverter.targetIdc                                    #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2847  #VsConverter.droop                                        #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2848  #VsConverter.droopCompensation                            #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2851  #VsConverter.qShare                                       #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2852  #VsConverter.targetQpcc                                   #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2853  #VsConverter.targetUpcc                                   #Package_SteadyStateHypothesisProfile  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1
# 2894  #ConnectivityNode.TopologicalNode                         #Package_TopologyProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1
# 2895  #ConnectivityNode.TopologicalNode                         #Package_TopologyBoundaryProfile       http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1
# 2902  #DCTopologicalNode.DCEquipmentContainer                   #Package_TopologyProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1
# 2905  #DCNode.DCTopologicalNode                                 #Package_TopologyProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1
# 2906  #TopologicalNode.Terminal                                 #Package_TopologyProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n
# 2907  #Terminal.TopologicalNode                                 #Package_TopologyProfile               http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1

# %%
report_name = "Comment"

markdown_print("# {}".format(report_name))

properties = {}
for data in data_set:
    
    # Here goes query
    property_data = data_set[data].merge(data_set[data].query("VALUE == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property'"), on="ID", suffixes=("", "_remove"))[data_set[data].columns].drop_duplicates()
    properties[data] = property_data.query("KEY=='comment'")


common_property = properties["new"].merge(properties["old"], on=["ID","KEY", "INSTANCE_ID"], how="inner", suffixes=("_new", "_old"))
print("Common " + str(len(common_property)))


changes = common_property[~(common_property["VALUE_new"] == common_property["VALUE_old"])][["ID", "INSTANCE_ID", "VALUE_old", "VALUE_new"]]
print("Changes " + str(len(changes)))
display(changes)
# Out:
# # Comment
# Common 2831
# Changes 2509
#                                                             ID                            INSTANCE_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         VALUE_old  \
# 0     #Diagram.orientation                                      #Package_DiagramLayoutProfile          Coordinate system orientation of the diagram.
# 13    #DiagramObject.rotation                                   #Package_DiagramLayoutProfile          Sets the angle of rotation of the diagram object.  Zero degrees is pointing to the top of the diagram.  Rotation is clockwise.
# 14    #IdentifiedObject.DiagramObjects                          #Package_DiagramLayoutProfile          The domain object to which this diagram object is associated.
# 15    #DiagramObject.IdentifiedObject                           #Package_DiagramLayoutProfile          The diagram objects that are associated with the domain object.
# 22    #DiagramObjectGluePoint.DiagramObjectPoints               #Package_DiagramLayoutProfile          The 'glue' point to which this point is associated.
# 23    #DiagramObjectPoint.DiagramObjectGluePoint                #Package_DiagramLayoutProfile          A diagram object glue point is associated with 2 or more object points that are considered to be 'glued' together.
# 24    #DiagramObjectPoint.sequenceNumber                        #Package_DiagramLayoutProfile          The sequence position of the point, used for defining the order of points for diagram objects acting as a polyline or polygon with more than one point.
# 28    #IdentifiedObject.mRID                                    #Package_DiagramLayoutProfile          Master resource identifier issued by a model authority. The mRID is globally unique within an exchange context. Global uniqueness is easily achieved by using a UUID,  as specified in RFC 4122, for the mRID.  The use of UUID is strongly recommended.\nFor CIMXML data files in RDF syntax conforming to IEC 61970-552 Edition 1, the mRID is mapped to rdf:ID or rdf:about attributes that identify CIM object elements.
# 29    #IdentifiedObject.mRID                                    #Package_DynamicsProfile               Master resource identifier issued by a model authority. The mRID is globally unique within an exchange context. Global uniqueness is easily achieved by using a UUID,  as specified in RFC 4122, for the mRID.  The use of UUID is strongly recommended.\nFor CIMXML data files in RDF syntax conforming to IEC 61970-552 Edition 1, the mRID is mapped to rdf:ID or rdf:about attributes that identify CIM object elements.
# 30    #IdentifiedObject.mRID                                    #Package_EquipmentBoundaryProfile      Master resource identifier issued by a model authority. The mRID is globally unique within an exchange context. Global uniqueness is easily achieved by using a UUID,  as specified in RFC 4122, for the mRID.  The use of UUID is strongly recommended.\nFor CIMXML data files in RDF syntax conforming to IEC 61970-552 Edition 1, the mRID is mapped to rdf:ID or rdf:about attributes that identify CIM object elements.
# 31    #IdentifiedObject.mRID                                    #Package_GeographicalLocationProfile   Master resource identifier issued by a model authority. The mRID is globally unique within an exchange context. Global uniqueness is easily achieved by using a UUID,  as specified in RFC 4122, for the mRID.  The use of UUID is strongly recommended.\nFor CIMXML data files in RDF syntax conforming to IEC 61970-552 Edition 1, the mRID is mapped to rdf:ID or rdf:about attributes that identify CIM object elements.
# 32    #IdentifiedObject.mRID                                    #Package_SteadyStateHypothesisProfile  Master resource identifier issued by a model authority. The mRID is globally unique within an exchange context. Global uniqueness is easily achieved by using a UUID,  as specified in RFC 4122, for the mRID.  The use of UUID is strongly recommended.\nFor CIMXML data files in RDF syntax conforming to IEC 61970-552 Edition 1, the mRID is mapped to rdf:ID or rdf:about attributes that identify CIM object elements.
# 33    #IdentifiedObject.mRID                                    #Package_StateVariablesProfile         Master resource identifier issued by a model authority. The mRID is globally unique within an exchange context. Global uniqueness is easily achieved by using a UUID,  as specified in RFC 4122, for the mRID.  The use of UUID is strongly recommended.\nFor CIMXML data files in RDF syntax conforming to IEC 61970-552 Edition 1, the mRID is mapped to rdf:ID or rdf:about attributes that identify CIM object elements.
# 34    #IdentifiedObject.mRID                                    #Package_TopologyProfile               Master resource identifier issued by a model authority. The mRID is globally unique within an exchange context. Global uniqueness is easily achieved by using a UUID,  as specified in RFC 4122, for the mRID.  The use of UUID is strongly recommended.\nFor CIMXML data files in RDF syntax conforming to IEC 61970-552 Edition 1, the mRID is mapped to rdf:ID or rdf:about attributes that identify CIM object elements.
# 35    #IdentifiedObject.mRID                                    #Package_TopologyBoundaryProfile       Master resource identifier issued by a model authority. The mRID is globally unique within an exchange context. Global uniqueness is easily achieved by using a UUID,  as specified in RFC 4122, for the mRID.  The use of UUID is strongly recommended.\nFor CIMXML data files in RDF syntax conforming to IEC 61970-552 Edition 1, the mRID is mapped to rdf:ID or rdf:about attributes that identify CIM object elements.
# 57    #AsynchronousMachine.AsynchronousMachineDynamics          #Package_DynamicsProfile               Asynchronous machine dynamics model used to describe dynamic behavior of this asynchronous machine.
# 59    #EnergyConsumer.LoadDynamics                              #Package_DynamicsProfile               Load dynamics model used to describe dynamic behavior of this energy consumer.
# 61    #SynchronousMachine.SynchronousMachineDynamics            #Package_DynamicsProfile               Synchronous machine dynamics model used to describe dynamic behavior of this synchronous machine.
# 65    #WindTurbineType1or2Dynamics.RemoteInputSignal            #Package_DynamicsProfile               Remote input signal used by this wind generator Type 1 or Type 2 model.
# 66    #RemoteInputSignal.WindTurbineType1or2Dynamics            #Package_DynamicsProfile               Wind generator Type 1 or Type 2 model using this remote input signal.
# 71    #PFVArControllerType1Dynamics.RemoteInputSignal           #Package_DynamicsProfile               Remote input signal used by this Power Factor or VAr controller Type I model.
# 72    #RemoteInputSignal.PFVArControllerType1Dynamics           #Package_DynamicsProfile               Power Factor or VAr controller Type I model using this remote input signal.
# 75    #RemoteInputSignal.WindPlantDynamics                      #Package_DynamicsProfile               The remote signal with which this power plant is associated.
# 76    #WindPlantDynamics.RemoteInputSignal                      #Package_DynamicsProfile               The wind plant using the remote signal.
# 77    #RemoteInputSignal.WindTurbineType3or4Dynamics            #Package_DynamicsProfile               Remote input signal used by these wind turbine Type 3 or 4 models.
# 78    #WindTurbineType3or4Dynamics.RemoteInputSignal            #Package_DynamicsProfile               Wind turbine Type 3 or 4 models using this remote input signal.
# 80    #RotatingMachineDynamics.damping                          #Package_DynamicsProfile               Damping torque coefficient (D).  A proportionality constant that, when multiplied by the angular velocity of the rotor poles with respect to the magnetic field (frequency), results in the damping torque.  This value is often zero when the sources of damping torques (generator damper windings, load damping effects, etc.) are modelled in detail.  Typical Value = 0.
# 81    #RotatingMachineDynamics.inertia                          #Package_DynamicsProfile               Inertia constant of generator or motor and mechanical load (H) (>0).  This is the specification for the stored energy in the rotating mass when operating at rated speed.  For a generator, this includes the generator plus all other elements (turbine, exciter) on the same shaft and has units of MW*sec.  For a motor, it includes the motor plus its mechanical load. Conventional units are per unit on the generator MVA base, usually expressed as MW*second/MVA or just second.   This value is used in the accelerating power reference frame for operator training simulator solutions.  Typical Value = 3.
# 82    #RotatingMachineDynamics.saturationFactor                 #Package_DynamicsProfile               Saturation factor at rated terminal voltage (S1) (> or =0).  Not used by simplified model.  Defined by defined by S(E1) in the SynchronousMachineSaturationParameters diagram.  Typical Value = 0.02.
# 83    #RotatingMachineDynamics.saturationFactor120              #Package_DynamicsProfile               Saturation factor at 120% of rated terminal voltage (S12) (> or =S1). Not used by the simplified model, defined by S(E2) in the SynchronousMachineSaturationParameters diagram.  Typical Value = 0.12.
# 84    #RotatingMachineDynamics.statorLeakageReactance           #Package_DynamicsProfile               Stator leakage reactance (Xl) (> or =0). Typical Value = 0.15.
# 85    #RotatingMachineDynamics.statorResistance                 #Package_DynamicsProfile               Stator (armature) resistance (Rs) (> or =0). Typical Value = 0.005.
# 86    #WindPlantUserDefined.proprietary                         #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 89    #WindType1or2UserDefined.proprietary                      #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 92    #WindType3or4UserDefined.proprietary                      #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 95    #SynchronousMachineUserDefined.proprietary                #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 98    #AsynchronousMachineUserDefined.proprietary               #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 101   #TurbineGovernorUserDefined.proprietary                   #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 104   #TurbineLoadControllerUserDefined.proprietary             #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 107   #MechanicalLoadUserDefined.proprietary                    #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 110   #ExcitationSystemUserDefined.proprietary                  #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 113   #OverexcitationLimiterUserDefined.proprietary             #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 116   #UnderexcitationLimiterUserDefined.proprietary            #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 119   #PowerSystemStabilizerUserDefined.proprietary             #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 122   #DiscontinuousExcitationControlUserDefined.proprietary    #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 125   #PFVArControllerType1UserDefined.proprietary              #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 128   #VoltageAdjusterUserDefined.proprietary                   #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 131   #PFVArControllerType2UserDefined.proprietary              #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 134   #VoltageCompensatorUserDefined.proprietary                #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 137   #LoadUserDefined.proprietary                              #Package_DynamicsProfile               Behaviour is based on proprietary model as opposed to detailed model.\ntrue = user-defined model is proprietary with behaviour mutually understood by sending and receiving applications and parameters passed as general attributes\nfalse = user-defined model is explicitly defined in terms of control blocks and their input and output signals.
# 141   #ProprietaryParameterDynamics.booleanParameterValue       #Package_DynamicsProfile               Used for boolean parameter value. If this attribute is populated, integerParameterValue and floatParameterValue will not be.
# 142   #ProprietaryParameterDynamics.integerParameterValue       #Package_DynamicsProfile               Used for integer parameter value.  If this attribute is populated, booleanParameterValue and floatParameterValue will not be.
# 143   #ProprietaryParameterDynamics.floatParameterValue         #Package_DynamicsProfile               Used for floating point parameter value.  If this attribute is populated, booleanParameterValue and integerParameterValue will not be.
# 144   #MechanicalLoadDynamics.SynchronousMachineDynamics        #Package_DynamicsProfile               Synchronous machine model with which this mechanical load model is associated.
# 148   #TurbineGovernorDynamics.SynchronousMachineDynamics       #Package_DynamicsProfile               Turbine-governor model associated with this synchronous machine model.
# 149   #SynchronousMachineDynamics.TurbineGovernorDynamics       #Package_DynamicsProfile               Synchronous machine model with which this turbine-governor model is associated.
# 152   #SynchronousMachineDetailed.saturationFactorQAxis         #Package_DynamicsProfile               Q-axis saturation factor at rated terminal voltage (S1q) (>= 0). Typical Value = 0.02.
# 153   #SynchronousMachineDetailed.saturationFactor120QAxis      #Package_DynamicsProfile               Q-axis saturation factor at 120% of rated terminal voltage (S12q) (>=S1q).  Typical Value = 0.12.
# 154   #SynchronousMachineDetailed.efdBaseRatio                  #Package_DynamicsProfile               Ratio of Efd bases of exciter and generator models.  Typical Value = 1.
# ...
# 2804  The state voltage associated with the topological node.
# 2805  The topological node associated with the voltage state.
# 2810  Angle between VsConverter.uv and ACDCConverter.uc. It is converter’s state variable used in power flow. The attribute shall be a positive value or zero.
# 2811  The base voltage of the topological node.
# 2812  The base voltage of the topological node.
# 2815  The connectivity nodes combine together to form this topological node.  May depend on the current state of switches in the network.
# 2817  The topological node to which this connectivity node is assigned.  May depend on the current state of switches in the network.
# 2819  The connectivity node container to which the topological node belongs.
# 2820  The connectivity node container to which the topological node belongs.
# 2823  See association end TopologicalNode.Terminal.
# 2824  See association end Terminal.TopologicalNode.
# 2825  The DC connectivity nodes combined together to form this DC topological node.  May depend on the current state of switches in the network.
# 2826  The DC topological node to which this DC connectivity node is assigned.  May depend on the current state of switches in the network.
# 2827  The terminals associated with the topological node.   This can be used as an alternative to the connectivity node path to terminal, thus making it unnecessary to model connectivity nodes in some cases.   Note that if connectivity nodes are in the model, this association would probably not be used as an input specification.
# 2828  The topological node associated with the terminal.   This can be used as an alternative to the connectivity node path to topological node, thus making it unnecessary to model connectivity nodes in some cases.   Note that the if connectivity nodes are in the model, this association would probably not be used as an input specification.
# 2829  The topological nodes that belong to the reporting group.
# 2830  The reporting group to which the topological node belongs.
#
# [2509 rows x 4 columns]

# %%
data_set["new"].query("ID=='#RotatingMachineDynamics.damping'")
# Out:
#                                     ID           KEY                                                          VALUE               INSTANCE_ID
# 3253  #RotatingMachineDynamics.damping  Type          Description                                                    #Package_DynamicsProfile
# 3254  #RotatingMachineDynamics.damping  stereotype    http://iec.ch/TC57/NonStandard/UML#attribute                   #Package_DynamicsProfile
# 3255  #RotatingMachineDynamics.damping  label         damping                                                        #Package_DynamicsProfile
# 3256  #RotatingMachineDynamics.damping  domain        #RotatingMachineDynamics                                       #Package_DynamicsProfile
# 3257  #RotatingMachineDynamics.damping  dataType      #Float                                                         #Package_DynamicsProfile
# 3258  #RotatingMachineDynamics.damping  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_DynamicsProfile
# 3259  #RotatingMachineDynamics.damping  comment       Damping torque coefficient (                                   #Package_DynamicsProfile
# 3260  #RotatingMachineDynamics.damping  type          http://www.w3.org/1999/02/22-rdf-syntax-ns#Property            #Package_DynamicsProfile

# %%
property_data
# Out:
#                                                                  ID              KEY                                                                                                                                                                                                                                                                                                                              VALUE                INSTANCE_ID
# 0       #EquipmentVersion.baseUML                                    Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 4       #EquipmentVersion.baseUML                                    stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 8       #EquipmentVersion.baseUML                                    label            baseUML                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 12      #EquipmentVersion.baseUML                                    domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 16      #EquipmentVersion.baseUML                                    dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 20      #EquipmentVersion.baseUML                                    multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 24      #EquipmentVersion.baseUML                                    isFixed          iec61970cim16v28_iec61968cim12v08_iec62325cim03v01a                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 28      #EquipmentVersion.baseUML                                    comment          Base UML provided by CIM model manager.                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 32      #EquipmentVersion.baseUML                                    type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 144     #EquipmentVersion.baseURIcore                                Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 148     #EquipmentVersion.baseURIcore                                stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 152     #EquipmentVersion.baseURIcore                                label            baseURIcore                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 156     #EquipmentVersion.baseURIcore                                domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 160     #EquipmentVersion.baseURIcore                                dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 164     #EquipmentVersion.baseURIcore                                multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 168     #EquipmentVersion.baseURIcore                                isFixed          http://iec.ch/TC57/2013/61970-452/EquipmentCore/4                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 172     #EquipmentVersion.baseURIcore                                comment          Profile URI used in the Model Exchange header and defined in IEC standards.  It uniquely identifies the Profile and its version. It is given for information only and to identify the closest IEC profile to which this CGMES profile is based on.                                                                                 #Package_EquipmentProfile
# 176     #EquipmentVersion.baseURIcore                                type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 288     #EquipmentVersion.baseURIoperation                           Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 292     #EquipmentVersion.baseURIoperation                           stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 296     #EquipmentVersion.baseURIoperation                           label            baseURIoperation                                                                                                                                                                                                                                                                                                                   #Package_EquipmentProfile
# 300     #EquipmentVersion.baseURIoperation                           domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 304     #EquipmentVersion.baseURIoperation                           dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 308     #EquipmentVersion.baseURIoperation                           multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 312     #EquipmentVersion.baseURIoperation                           isFixed          http://iec.ch/TC57/2013/61970-452/EquipmentOperation/4                                                                                                                                                                                                                                                                             #Package_EquipmentProfile
# 316     #EquipmentVersion.baseURIoperation                           comment          Profile URI used in the Model Exchange header and defined in IEC standards.  It uniquely identifies the Profile and its version. It is given for information only and to identify the closest IEC profile to which this CGMES profile is based on.                                                                                 #Package_EquipmentProfile
# 320     #EquipmentVersion.baseURIoperation                           type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 432     #EquipmentVersion.baseURIshortCircuit                        Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 436     #EquipmentVersion.baseURIshortCircuit                        stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 440     #EquipmentVersion.baseURIshortCircuit                        label            baseURIshortCircuit                                                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 444     #EquipmentVersion.baseURIshortCircuit                        domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 448     #EquipmentVersion.baseURIshortCircuit                        dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 452     #EquipmentVersion.baseURIshortCircuit                        multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 456     #EquipmentVersion.baseURIshortCircuit                        isFixed          http://iec.ch/TC57/2013/61970-452/EquipmentShortCircuit/4                                                                                                                                                                                                                                                                          #Package_EquipmentProfile
# 460     #EquipmentVersion.baseURIshortCircuit                        comment          Profile URI used in the Model Exchange header and defined in IEC standards.  It uniquely identifies the Profile and its version. It is given for information only and to identify the closest IEC profile to which this CGMES profile is based on.                                                                                 #Package_EquipmentProfile
# 464     #EquipmentVersion.baseURIshortCircuit                        type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 576     #EquipmentVersion.date                                       Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 580     #EquipmentVersion.date                                       stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 584     #EquipmentVersion.date                                       label            date                                                                                                                                                                                                                                                                                                                               #Package_EquipmentProfile
# 588     #EquipmentVersion.date                                       domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 592     #EquipmentVersion.date                                       dataType         #Date                                                                                                                                                                                                                                                                                                                              #Package_EquipmentProfile
# 596     #EquipmentVersion.date                                       multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 600     #EquipmentVersion.date                                       isFixed          2014-08-07                                                                                                                                                                                                                                                                                                                         #Package_EquipmentProfile
# 604     #EquipmentVersion.date                                       comment          Profile creation date\nForm is YYYY-MM-DD for example for January 5, 2009 it is 2009-01-05.                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 608     #EquipmentVersion.date                                       type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 720     #EquipmentVersion.differenceModelURI                         Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 724     #EquipmentVersion.differenceModelURI                         stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 728     #EquipmentVersion.differenceModelURI                         label            differenceModelURI                                                                                                                                                                                                                                                                                                                 #Package_EquipmentProfile
# 732     #EquipmentVersion.differenceModelURI                         domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 736     #EquipmentVersion.differenceModelURI                         dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 740     #EquipmentVersion.differenceModelURI                         multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 744     #EquipmentVersion.differenceModelURI                         isFixed          http://iec.ch/TC57/61970-552/DifferenceModel/1#                                                                                                                                                                                                                                                                                    #Package_EquipmentProfile
# 748     #EquipmentVersion.differenceModelURI                         comment          Difference model URI defined by IEC 61970-552.                                                                                                                                                                                                                                                                                     #Package_EquipmentProfile
# 752     #EquipmentVersion.differenceModelURI                         type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 864     #EquipmentVersion.entsoeUML                                  Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 868     #EquipmentVersion.entsoeUML                                  stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 872     #EquipmentVersion.entsoeUML                                  label            entsoeUML                                                                                                                                                                                                                                                                                                                          #Package_EquipmentProfile
# 876     #EquipmentVersion.entsoeUML                                  domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 880     #EquipmentVersion.entsoeUML                                  dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 884     #EquipmentVersion.entsoeUML                                  multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 888     #EquipmentVersion.entsoeUML                                  isFixed          entsoe_v2.4.15                                                                                                                                                                                                                                                                                                                     #Package_EquipmentProfile
# 892     #EquipmentVersion.entsoeUML                                  comment          UML provided by ENTSO-E.                                                                                                                                                                                                                                                                                                           #Package_EquipmentProfile
# 896     #EquipmentVersion.entsoeUML                                  type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 1008    #EquipmentVersion.entsoeURIcore                              Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 1012    #EquipmentVersion.entsoeURIcore                              stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 1016    #EquipmentVersion.entsoeURIcore                              label            entsoeURIcore                                                                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 1020    #EquipmentVersion.entsoeURIcore                              domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 1024    #EquipmentVersion.entsoeURIcore                              dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 1028    #EquipmentVersion.entsoeURIcore                              multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 1032    #EquipmentVersion.entsoeURIcore                              isFixed          http://entsoe.eu/CIM/EquipmentCore/3/1                                                                                                                                                                                                                                                                                             #Package_EquipmentProfile
# 1036    #EquipmentVersion.entsoeURIcore                              comment          Profile URI defined by ENTSO-E and used in the Model Exchange header.  It uniquely identifies the Profile and its version. The last two elements in the URI (http://entsoe.eu/CIM/EquipmentCore/yy/zzz) indicate major and minor versions where: \n- yy - indicates a major version;\n- zzz - indicates a minor version.           #Package_EquipmentProfile
# 1040    #EquipmentVersion.entsoeURIcore                              type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 1152    #EquipmentVersion.entsoeURIoperation                         Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 1156    #EquipmentVersion.entsoeURIoperation                         stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 1160    #EquipmentVersion.entsoeURIoperation                         label            entsoeURIoperation                                                                                                                                                                                                                                                                                                                 #Package_EquipmentProfile
# 1164    #EquipmentVersion.entsoeURIoperation                         domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 1168    #EquipmentVersion.entsoeURIoperation                         dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 1172    #EquipmentVersion.entsoeURIoperation                         multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 1176    #EquipmentVersion.entsoeURIoperation                         isFixed          http://entsoe.eu/CIM/EquipmentOperation/3/1                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 1180    #EquipmentVersion.entsoeURIoperation                         comment          Profile URI defined by ENTSO-E and used in the Model Exchange header.  It uniquely identifies the Profile and its version. The last two elements in the URI (http://entsoe.eu/CIM/EquipmentOperation/yy/zzz) indicate major and minor versions where: \n- yy - indicates a major version;\n- zzz - indicates a minor version.      #Package_EquipmentProfile
# 1184    #EquipmentVersion.entsoeURIoperation                         type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 1296    #EquipmentVersion.entsoeURIshortCircuit                      Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 1300    #EquipmentVersion.entsoeURIshortCircuit                      stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 1304    #EquipmentVersion.entsoeURIshortCircuit                      label            entsoeURIshortCircuit                                                                                                                                                                                                                                                                                                              #Package_EquipmentProfile
# 1308    #EquipmentVersion.entsoeURIshortCircuit                      domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 1312    #EquipmentVersion.entsoeURIshortCircuit                      dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 1316    #EquipmentVersion.entsoeURIshortCircuit                      multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 1320    #EquipmentVersion.entsoeURIshortCircuit                      isFixed          http://entsoe.eu/CIM/EquipmentShortCircuit/3/1                                                                                                                                                                                                                                                                                     #Package_EquipmentProfile
# 1324    #EquipmentVersion.entsoeURIshortCircuit                      comment          Profile URI defined by ENTSO-E and used in the Model Exchange header.  It uniquely identifies the Profile and its version. The last two elements in the URI (http://entsoe.eu/CIM/EquipmentShortCircuit/yy/zzz) indicate major and minor versions where: \n- yy - indicates a major version;\n- zzz - indicates a minor version.   #Package_EquipmentProfile
# 1328    #EquipmentVersion.entsoeURIshortCircuit                      type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 1440    #EquipmentVersion.modelDescriptionURI                        Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 1444    #EquipmentVersion.modelDescriptionURI                        stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 1448    #EquipmentVersion.modelDescriptionURI                        label            modelDescriptionURI                                                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 1452    #EquipmentVersion.modelDescriptionURI                        domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 1456    #EquipmentVersion.modelDescriptionURI                        dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 1460    #EquipmentVersion.modelDescriptionURI                        multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 1464    #EquipmentVersion.modelDescriptionURI                        isFixed          http://iec.ch/TC57/61970-552/ModelDescription/1#                                                                                                                                                                                                                                                                                   #Package_EquipmentProfile
# 1468    #EquipmentVersion.modelDescriptionURI                        comment          Model Description URI defined by IEC 61970-552.                                                                                                                                                                                                                                                                                    #Package_EquipmentProfile
# 1472    #EquipmentVersion.modelDescriptionURI                        type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 1584    #EquipmentVersion.namespaceRDF                               Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 1588    #EquipmentVersion.namespaceRDF                               stereotype       http://iec.ch/TC57/NonStandard/UML#attribute                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 1592    #EquipmentVersion.namespaceRDF                               label            namespaceRDF                                                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 1596    #EquipmentVersion.namespaceRDF                               domain           #EquipmentVersion                                                                                                                                                                                                                                                                                                                  #Package_EquipmentProfile
# 1600    #EquipmentVersion.namespaceRDF                               dataType         #String                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 1604    #EquipmentVersion.namespaceRDF                               multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 1608    #EquipmentVersion.namespaceRDF                               isFixed          http://www.w3.org/1999/02/22-rdf-syntax-ns#                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 1612    #EquipmentVersion.namespaceRDF                               comment          RDF namespace.                                                                                                                                                                                                                                                                                                                     #Package_EquipmentProfile
# 1616    #EquipmentVersion.namespaceRDF                               type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 1728    #EquipmentVersion.namespaceUML                               Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# ...
# 154145  #TieFlow.ControlArea                                         Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 154147  #TieFlow.ControlArea                                         label            ControlArea                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 154149  #TieFlow.ControlArea                                         comment          The control area of the tie flows.                                                                                                                                                                                                                                                                                                 #Package_EquipmentProfile
# 154151  #TieFlow.ControlArea                                         domain           #TieFlow                                                                                                                                                                                                                                                                                                                           #Package_EquipmentProfile
# 154153  #TieFlow.ControlArea                                         range            #ControlArea                                                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 154155  #TieFlow.ControlArea                                         inverseRoleName  #ControlArea.TieFlow                                                                                                                                                                                                                                                                                                               #Package_EquipmentProfile
# 154157  #TieFlow.ControlArea                                         multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1                                                                                                                                                                                                                                                                         #Package_EquipmentProfile
# 154159  #TieFlow.ControlArea                                         AssociationUsed  Yes                                                                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 154161  #TieFlow.ControlArea                                         type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 154181  #ControlArea.TieFlow                                         Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 154183  #ControlArea.TieFlow                                         label            TieFlow                                                                                                                                                                                                                                                                                                                            #Package_EquipmentProfile
# 154185  #ControlArea.TieFlow                                         comment          The tie flows associated with the control area.                                                                                                                                                                                                                                                                                    #Package_EquipmentProfile
# 154187  #ControlArea.TieFlow                                         domain           #ControlArea                                                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 154189  #ControlArea.TieFlow                                         range            #TieFlow                                                                                                                                                                                                                                                                                                                           #Package_EquipmentProfile
# 154191  #ControlArea.TieFlow                                         inverseRoleName  #TieFlow.ControlArea                                                                                                                                                                                                                                                                                                               #Package_EquipmentProfile
# 154193  #ControlArea.TieFlow                                         multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 154195  #ControlArea.TieFlow                                         AssociationUsed  No                                                                                                                                                                                                                                                                                                                                 #Package_EquipmentProfile
# 154197  #ControlArea.TieFlow                                         type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 154217  #ControlAreaGeneratingUnit.ControlArea                       Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 154219  #ControlAreaGeneratingUnit.ControlArea                       label            ControlArea                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 154221  #ControlAreaGeneratingUnit.ControlArea                       comment          The parent control area for the generating unit specifications.                                                                                                                                                                                                                                                                    #Package_EquipmentProfile
# 154223  #ControlAreaGeneratingUnit.ControlArea                       domain           #ControlAreaGeneratingUnit                                                                                                                                                                                                                                                                                                         #Package_EquipmentProfile
# 154225  #ControlAreaGeneratingUnit.ControlArea                       range            #ControlArea                                                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 154227  #ControlAreaGeneratingUnit.ControlArea                       inverseRoleName  #ControlArea.ControlAreaGeneratingUnit                                                                                                                                                                                                                                                                                             #Package_EquipmentProfile
# 154229  #ControlAreaGeneratingUnit.ControlArea                       multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1                                                                                                                                                                                                                                                                         #Package_EquipmentProfile
# 154231  #ControlAreaGeneratingUnit.ControlArea                       AssociationUsed  Yes                                                                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 154233  #ControlAreaGeneratingUnit.ControlArea                       type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
# 154253  #ControlArea.ControlAreaGeneratingUnit                       Type             Description                                                                                                                                                                                                                                                                                                                        #Package_EquipmentProfile
# 154255  #ControlArea.ControlAreaGeneratingUnit                       label            ControlAreaGeneratingUnit                                                                                                                                                                                                                                                                                                          #Package_EquipmentProfile
# 154257  #ControlArea.ControlAreaGeneratingUnit                       comment          The generating unit specificaitons for the control area.                                                                                                                                                                                                                                                                           #Package_EquipmentProfile
# 154259  #ControlArea.ControlAreaGeneratingUnit                       domain           #ControlArea                                                                                                                                                                                                                                                                                                                       #Package_EquipmentProfile
# 154261  #ControlArea.ControlAreaGeneratingUnit                       range            #ControlAreaGeneratingUnit                                                                                                                                                                                                                                                                                                         #Package_EquipmentProfile
# 154263  #ControlArea.ControlAreaGeneratingUnit                       inverseRoleName  #ControlAreaGeneratingUnit.ControlArea                                                                                                                                                                                                                                                                                             #Package_EquipmentProfile
# 154265  #ControlArea.ControlAreaGeneratingUnit                       multiplicity     http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n                                                                                                                                                                                                                                                                      #Package_EquipmentProfile
# 154267  #ControlArea.ControlAreaGeneratingUnit                       AssociationUsed  No                                                                                                                                                                                                                                                                                                                                 #Package_EquipmentProfile
# 154269  #ControlArea.ControlAreaGeneratingUnit                       type             http://www.w3.org/1999/02/22-rdf-syntax-ns#Property                                                                                                                                                                                                                                                                                #Package_EquipmentProfile
#
# [30445 rows x 4 columns]

# %%
property_data = data_set[data].merge(data_set[data][~data_set[data].ID.str.contains("Version")].query("VALUE == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property'"), on="ID", suffixes=("", "_remove"))[data_set[data].columns].drop_duplicates()

# %%
property_data.query("KEY=='multiplicity'")
# Out:
#                                                                  ID           KEY                                                          VALUE                            INSTANCE_ID
# 20      #ACDCConverter.baseS                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 158     #ApparentPower.value                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 200     #ApparentPower.value                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 410     #ApparentPower.unit                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 458     #ApparentPower.unit                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 698     #ApparentPower.multiplier                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 746     #ApparentPower.multiplier                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 976     #ACDCConverter.idleLoss                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 1124    #ActivePower.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 1180    #ActivePower.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 1236    #ActivePower.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 1292    #ActivePower.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 1572    #ActivePower.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 1636    #ActivePower.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 1700    #ActivePower.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 1764    #ActivePower.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 2084    #ActivePower.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 2148    #ActivePower.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 2212    #ActivePower.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 2276    #ActivePower.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 2576    #ACDCConverter.maxUdc                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 2719    #Voltage.value                                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 2768    #Voltage.value                                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 2817    #Voltage.value                                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 2866    #Voltage.value                                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentBoundaryProfile
# 3062    #Voltage.unit                                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 3118    #Voltage.unit                                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 3174    #Voltage.unit                                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 3230    #Voltage.unit                                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentBoundaryProfile
# 3454    #Voltage.multiplier                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 3510    #Voltage.multiplier                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 3566    #Voltage.multiplier                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 3622    #Voltage.multiplier                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentBoundaryProfile
# 3831    #ACDCConverter.minUdc                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 3959    #ACDCConverter.numberOfValves                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 4087    #ACDCConverter.ratedUdc                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 4215    #ACDCConverter.resistiveLoss                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 4348    #Resistance.value                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 4383    #Resistance.value                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 4523    #Resistance.unit                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 4563    #Resistance.unit                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 4723    #Resistance.multiplier                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 4763    #Resistance.multiplier                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 4918    #ACDCConverter.switchingLoss                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 5046    #ActivePowerPerCurrentFlow.denominatorMultiplier             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 5174    #ActivePowerPerCurrentFlow.denominatorUnit                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 5302    #ActivePowerPerCurrentFlow.multiplier                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 5430    #ActivePowerPerCurrentFlow.unit                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 5558    #ActivePowerPerCurrentFlow.value                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 5670    #ACDCConverter.valveU0                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 5798    #ACDCConverterDCTerminal.polarity                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 5926    #CsConverter.maxAlpha                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 6079    #AngleDegrees.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 6142    #AngleDegrees.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 6205    #AngleDegrees.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 6268    #AngleDegrees.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DiagramLayoutProfile
# 6331    #AngleDegrees.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 6646    #AngleDegrees.unit                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 6718    #AngleDegrees.unit                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 6790    #AngleDegrees.unit                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 6862    #AngleDegrees.unit                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DiagramLayoutProfile
# 6934    #AngleDegrees.unit                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 7294    #AngleDegrees.multiplier                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 7366    #AngleDegrees.multiplier                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 7438    #AngleDegrees.multiplier                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 7510    #AngleDegrees.multiplier                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DiagramLayoutProfile
# 7582    #AngleDegrees.multiplier                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 7917    #CsConverter.maxGamma                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 8045    #CsConverter.maxIdc                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 8193    #CurrentFlow.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 8249    #CurrentFlow.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 8305    #CurrentFlow.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 8361    #CurrentFlow.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 8641    #CurrentFlow.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 8705    #CurrentFlow.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 8769    #CurrentFlow.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 8833    #CurrentFlow.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 9153    #CurrentFlow.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 9217    #CurrentFlow.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_StateVariablesProfile
# 9281    #CurrentFlow.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 9345    #CurrentFlow.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 9645    #CsConverter.minAlpha                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 9773    #CsConverter.minGamma                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 9901    #CsConverter.minIdc                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 10029   #CsConverter.ratedIdc                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 10157   #DCConverterUnit.operationMode                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 10269   #DCGround.inductance                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 10397   #Inductance.value                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 10509   #Inductance.unit                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 10637   #Inductance.multiplier                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 10765   #DCGround.r                                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 10893   #DCLineSegment.capacitance                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 11021   #Capacitance.value                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 11133   #Capacitance.unit                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 11261   #Capacitance.multiplier                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 11389   #DCLineSegment.inductance                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 11517   #DCLineSegment.resistance                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 11645   #DCLineSegment.length                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 11783   #Length.value                                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 11825   #Length.value                                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 12035   #Length.unit                                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 12083   #Length.unit                                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 12323   #Length.multiplier                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 12371   #Length.multiplier                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_DynamicsProfile
# 12601   #DCSeriesDevice.inductance                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 12729   #DCSeriesDevice.resistance                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 12857   #DCSeriesDevice.ratedUdc                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 12985   #DCShunt.capacitance                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 13113   #DCShunt.resistance                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 13241   #DCShunt.ratedUdc                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 13369   #PerLengthDCLineParameter.capacitance                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 13497   #CapacitancePerLength.value                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 13609   #CapacitancePerLength.unit                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 13737   #CapacitancePerLength.multiplier                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 13865   #CapacitancePerLength.denominatorUnit                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 13993   #CapacitancePerLength.denominatorMultiplier                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 14121   #PerLengthDCLineParameter.inductance                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 14249   #InductancePerLength.value                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 14361   #InductancePerLength.unit                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 14489   #InductancePerLength.multiplier                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 14617   #InductancePerLength.denominatorUnit                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 14745   #InductancePerLength.denominatorMultiplier                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 14873   #PerLengthDCLineParameter.resistance                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 15001   #ResistancePerLength.value                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 15113   #ResistancePerLength.unit                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 15241   #ResistancePerLength.multiplier                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 15369   #ResistancePerLength.denominatorUnit                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 15497   #ResistancePerLength.denominatorMultiplier                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 15625   #VsConverter.maxModulationIndex                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 15778   #Simple_Float.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 15841   #Simple_Float.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_StateVariablesProfile
# 15904   #Simple_Float.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_SteadyStateHypothesisProfile
# 15967   #Simple_Float.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_DiagramLayoutProfile
# 16030   #Simple_Float.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_DynamicsProfile
# 16320   #VsConverter.maxValveCurrent                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 16448   #BusNameMarker.priority                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 16581   #PerCent.value                                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 16621   #PerCent.value                                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 16781   #PerCent.unit                                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 16821   #PerCent.unit                                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 16981   #PerCent.multiplier                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 17021   #PerCent.multiplier                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_SteadyStateHypothesisProfile
# 17176   #EnergySource.nominalVoltage                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 17304   #EnergySource.r                                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 17432   #EnergySource.r0                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 17560   #EnergySource.rn                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 17688   #EnergySource.voltageAngle                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 17816   #AngleRadians.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 17928   #AngleRadians.unit                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 18056   #AngleRadians.multiplier                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 18184   #EnergySource.voltageMagnitude                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 18312   #EnergySource.x                                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 18440   #Reactance.value                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 18552   #Reactance.unit                                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 18680   #Reactance.multiplier                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 18808   #EnergySource.x0                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 18936   #EnergySource.xn                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 19064   #FossilFuel.fossilFuelType                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 19192   #GeneratingUnit.genControlSource                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 19320   #GeneratingUnit.governorSCD                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 19448   #GeneratingUnit.initialP                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 19576   #GeneratingUnit.longPF                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 19704   #GeneratingUnit.maximumAllowableSpinningReserve              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 19832   #GeneratingUnit.maxOperatingP                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 19960   #GeneratingUnit.minOperatingP                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 20088   #GeneratingUnit.nominalP                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 20216   #GeneratingUnit.ratedGrossMaxP                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 20344   #GeneratingUnit.ratedGrossMinP                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 20472   #GeneratingUnit.ratedNetMaxP                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 20600   #GeneratingUnit.shortPF                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 20728   #GeneratingUnit.startupCost                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 20856   #Money.unit                                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 20984   #Money.multiplier                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 21112   #Money.value                                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 21224   #GeneratingUnit.variableCost                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# ...                              ...                                          ...                                                            ...                        ...
# 145152  #DiscreteValue.value                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 145184  #LimitSet.isPercentageLimits                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145216  #Measurement.measurementType                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 145248  #Measurement.phases                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145280  #Measurement.unitSymbol                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 145312  #Measurement.unitMultiplier                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 145346  #Measurement.Terminal                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145382  #ACDCTerminal.Measurements                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 145418  #Measurement.PowerSystemResource                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 145454  #PowerSystemResource.Measurements                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 145488  #MeasurementValue.timeStamp                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145520  #MeasurementValue.sensorAccuracy                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145554  #MeasurementValueQuality.MeasurementValue                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 145590  #MeasurementValue.MeasurementValueQuality                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145626  #MeasurementValue.MeasurementValueSource                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 145662  #MeasurementValueSource.MeasurementValues                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 145696  #Quality61850.badReference                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145728  #Quality61850.estimatorReplaced                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145760  #Quality61850.failure                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145792  #Quality61850.oldData                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145824  #Quality61850.operatorBlocked                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145856  #Quality61850.oscillatory                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145888  #Quality61850.outOfRange                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145920  #Quality61850.overFlow                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145952  #Quality61850.source                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 145984  #Quality61850.suspect                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 146016  #Quality61850.test                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 146048  #Quality61850.validity                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 146082  #RaiseLowerCommand.ValueAliasSet                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 146118  #ValueAliasSet.RaiseLowerCommands                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 146152  #SetPoint.normalValue                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146184  #SetPoint.value                                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146218  #StringMeasurementValue.StringMeasurement                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 146254  #StringMeasurement.StringMeasurementValues                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 146288  #StringMeasurementValue.value                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146322  #ValueToAlias.ValueAliasSet                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 146358  #ValueAliasSet.Values                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 146392  #ValueToAlias.value                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146426  #GrossToNetActivePowerCurve.GeneratingUnit                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 146462  #GeneratingUnit.GrossToNetActivePowerCurves                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 146502  #VoltageLevel.Bays                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 146538  #Bay.VoltageLevel                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 146574  #ConnectivityNode.Terminals                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 146610  #Terminal.ConnectivityNode                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146646  #RegularIntervalSchedule.TimePoints                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 146682  #RegularTimePoint.IntervalSchedule                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 146716  #RegularTimePoint.sequenceNumber                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146748  #RegularTimePoint.value1                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146780  #RegularTimePoint.value2                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 146812  #ActivePowerLimit.value                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146844  #ApparentPowerLimit.value                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 146876  #EnergyConsumer.pfixed                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 146912  #EnergyConsumer.pfixedPct                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 146948  #EnergyConsumer.qfixed                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 146984  #EnergyConsumer.qfixedPct                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 147022  #RegulationSchedule.RegulatingControl                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 147058  #RegulatingControl.RegulationSchedule                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147094  #SwitchSchedule.Switch                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 147130  #Switch.SwitchSchedules                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147166  #TapChanger.TapSchedules                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147202  #TapSchedule.TapChanger                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 147238  #SeasonDayTypeSchedule.DayType                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 147274  #DayType.SeasonDayTypeSchedules                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147310  #ControlArea.EnergyArea                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 147350  #EnergyArea.ControlArea                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 147390  #LoadArea.SubLoadAreas                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 147426  #SubLoadArea.LoadArea                                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 147462  #SubLoadArea.LoadGroups                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 147498  #LoadGroup.SubLoadArea                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 147532  #Season.endDate                                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 147564  #Season.startDate                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 147598  #SeasonDayTypeSchedule.Season                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 147634  #Season.SeasonDayTypeSchedules                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147668  #ACDCConverterDCTerminal.DCConductingEquipment               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 147700  #ACDCConverter.DCTerminals                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147734  #Terminal.ConverterDCSides                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147770  #ACDCConverter.PccTerminal                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 147804  #DCNode.DCTerminals                                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147836  #DCBaseTerminal.DCNode                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 147868  #DCConductingEquipment.DCTerminals                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 147900  #DCTerminal.DCConductingEquipment                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 147932  #DCConverterUnit.Substation                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 147964  #Substation.DCConverterUnit                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# ...
# 148198  #VsCapabilityCurve.VsConverterDCSides                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 148234  #VsConverter.CapabilityCurve                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148270  #ReportingGroup.BusNameMarker                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 148306  #BusNameMarker.ReportingGroup                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148342  #BusNameMarker.Terminal                                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 148378  #ACDCTerminal.BusNameMarker                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148414  #EnergySchedulingType.EnergySource                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 148450  #EnergySource.EnergySchedulingType                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148486  #ThermalGeneratingUnit.FossilFuels                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 148522  #FossilFuel.ThermalGeneratingUnit                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 148558  #ControlAreaGeneratingUnit.GeneratingUnit                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 148594  #GeneratingUnit.ControlAreaGeneratingUnit                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 148630  #RotatingMachine.GeneratingUnit                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148666  #GeneratingUnit.RotatingMachine                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 148702  #HydroPowerPlant.HydroGeneratingUnits                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 148738  #HydroGeneratingUnit.HydroPowerPlant                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148774  #HydroPowerPlant.HydroPumps                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 148810  #HydroPump.HydroPowerPlant                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148846  #HydroPump.RotatingMachine                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 148882  #RotatingMachine.HydroPump                                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148916  #OperationalLimitSet.Terminal                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 148948  #ACDCTerminal.OperationalLimitSet                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 148982  #ConductingEquipment.BaseVoltage                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 149018  #BaseVoltage.ConductingEquipment                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149054  #VoltageLevel.BaseVoltage                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 149090  #BaseVoltage.VoltageLevel                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149126  #TransformerEnd.BaseVoltage                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 149162  #BaseVoltage.TransformerEnds                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149198  #Curve.CurveDatas                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149234  #CurveData.Curve                                             multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 149270  #OperationalLimitSet.Equipment                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 149306  #Equipment.OperationalLimitSet                               multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149342  #SubGeographicalRegion.Substations                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149378  #Substation.Region                                           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 149414  #Substation.VoltageLevels                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149450  #VoltageLevel.Substation                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 149486  #RegulatingControl.Terminal                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 149522  #Terminal.RegulatingControl                                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 149558  #TieFlow.Terminal                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 149594  #Terminal.TieFlow                                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..2  #Package_EquipmentProfile
# 149630  #TransformerEnd.Terminal                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 149666  #Terminal.TransformerEnd                                     multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149702  #OperationalLimitSet.OperationalLimitValue                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149738  #OperationalLimit.OperationalLimitSet                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 149774  #OperationalLimit.OperationalLimitType                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 149810  #OperationalLimitType.OperationalLimit                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149846  #EnergyConsumer.LoadResponse                                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 149882  #LoadResponseCharacteristic.EnergyConsumer                   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 149918  #NonlinearShuntCompensatorPoint.NonlinearShuntCompensator    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 149954  #NonlinearShuntCompensator.NonlinearShuntCompensatorPoints   multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 149990  #PhaseTapChanger.TransformerEnd                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 150026  #TransformerEnd.PhaseTapChanger                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 150062  #PhaseTapChangerTablePoint.PhaseTapChangerTable              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 150098  #PhaseTapChangerTable.PhaseTapChangerTablePoint              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 150134  #PhaseTapChangerTable.PhaseTapChangerTabular                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 150170  #PhaseTapChangerTabular.PhaseTapChangerTable                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 150206  #PowerTransformerEnd.PowerTransformer                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..1  #Package_EquipmentProfile
# 150242  #PowerTransformer.PowerTransformerEnd                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 150278  #RatioTapChangerTable.RatioTapChanger                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 150314  #RatioTapChanger.RatioTapChangerTable                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 150350  #RatioTapChanger.TransformerEnd                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 150386  #TransformerEnd.RatioTapChanger                              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 150422  #RatioTapChangerTable.RatioTapChangerTablePoint              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 150458  #RatioTapChangerTablePoint.RatioTapChangerTable              multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 150494  #EquivalentInjection.ReactiveCapabilityCurve                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 150530  #ReactiveCapabilityCurve.EquivalentInjection                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 150566  #SynchronousMachine.InitialReactiveCapabilityCurve           multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 150602  #ReactiveCapabilityCurve.InitiallyUsedBySynchronousMachines  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 150638  #RegulatingCondEq.RegulatingControl                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 150674  #RegulatingControl.RegulatingCondEq                          multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 150710  #TapChangerControl.TapChanger                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 150746  #TapChanger.TapChangerControl                                multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 150782  #ConformLoadGroup.EnergyConsumers                            multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 150818  #ConformLoad.LoadGroup                                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 150854  #ConformLoadGroup.ConformLoadSchedules                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 150890  #ConformLoadSchedule.ConformLoadGroup                        multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 150926  #NonConformLoad.LoadGroup                                    multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 150962  #NonConformLoadGroup.EnergyConsumers                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1..n  #Package_EquipmentProfile
# 150998  #NonConformLoadGroup.NonConformLoadSchedules                 multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 151034  #NonConformLoadSchedule.NonConformLoadGroup                  multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 151070  #EquivalentNetwork.EquivalentEquipments                      multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 151106  #EquivalentEquipment.EquivalentNetwork                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..1  #Package_EquipmentProfile
# 151142  #TieFlow.ControlArea                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 151178  #ControlArea.TieFlow                                         multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
# 151214  #ControlAreaGeneratingUnit.ControlArea                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:1     #Package_EquipmentProfile
# 151250  #ControlArea.ControlAreaGeneratingUnit                       multiplicity  http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#M:0..n  #Package_EquipmentProfile
#
# [3645 rows x 4 columns]

# %%
#property_data.pivot(index="ID", columns="KEY", values="VALUE")

# %%
data_set[data].query("KEY == 'AssociationUsed' & VALUE == 'Yes'").merge(data_set[data], on="ID", suffixes=("remove",""))[data_set[data].columns]

# %%
topology = data_new.query("INSTANCE_ID == '#Package_TopologyBoundaryProfile'")

pandas.set_option("display.max_rows", 40)
pandas.set_option("display.max_columns", 20)

ClassCategory = 'http://iec.ch/TC57/1999/rdf-schema-extensions-19990926#ClassCategory'
Class = 'http://www.w3.org/2000/01/rdf-schema#Class'
Property = 'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property'

# %%
topology.query("VALUE == '{}'".format(Class))

# %%
topology.query("ID=='#String'")

# %%
topology.type_tableview("Description").query("type == '{}'".format(Class)).dropna(how="all", axis="columns")

# %%
topology.type_tableview("Description").query("type == '{}'".format(Class)).columns

# %%
validation_view(topology, "#TopologyBoundaryProfileVersion")

# %%
for ID in topology.query("VALUE == '{}'".format(Class)).ID:
    print(ID)
    display(parameter_tableview(topology, ID))
